# %%
import seaborn as sns
import pandas as pd
import numpy as np

import geopandas as gpd
from shapely.geometry import Point

from datetime import datetime

# !pip install pandas geopandas shapely


from sklearn.datasets import load_iris, fetch_california_housing
import matplotlib.pyplot as plt

from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor, NearestNeighbors
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor, RandomForestRegressor,AdaBoostRegressor, GradientBoostingRegressor

from sklearn.model_selection import train_test_split

from imblearn.over_sampling import SMOTE
# !pip install imbalanced-learn

from sklearn.metrics import mean_squared_error, mean_absolute_error

from sklearn.preprocessing import MinMaxScaler, StandardScaler
# Out:
# Requirement already satisfied: pandas in c:\users\ramya\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: geopandas in c:\users\ramya\anaconda3\lib\site-packages (0.14.4)
# Requirement already satisfied: shapely in c:\users\ramya\anaconda3\lib\site-packages (2.0.4)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\ramya\anaconda3\lib\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ramya\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ramya\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\ramya\anaconda3\lib\site-packages (from geopandas) (1.9.6)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\ramya\anaconda3\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: packaging in c:\users\ramya\anaconda3\lib\site-packages (from geopandas) (21.3)
# Requirement already satisfied: cligj>=0.5 in c:\users\ramya\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: click~=8.0 in c:\users\ramya\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (8.0.4)
# Requirement already satisfied: six in c:\users\ramya\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\ramya\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\ramya\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (21.4.0)
# Requirement already satisfied: certifi in c:\users\ramya\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (2024.2.2)
# Requirement already satisfied: importlib-metadata in c:\users\ramya\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas) (4.11.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ramya\anaconda3\lib\site-packages (from packaging->geopandas) (3.0.9)
# Requirement already satisfied: colorama in c:\users\ramya\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\ramya\anaconda3\lib\site-packages (from importlib-metadata->fiona>=1.8.21->geopandas) (3.8.0)
# Requirement already satisfied: imbalanced-learn in c:\users\ramya\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\ramya\anaconda3\lib\site-packages (from imbalanced-learn) (1.24.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\ramya\anaconda3\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ramya\anaconda3\lib\site-packages (from imbalanced-learn) (2.2.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\ramya\anaconda3\lib\site-packages (from imbalanced-learn) (1.0.2)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\ramya\anaconda3\lib\site-packages (from imbalanced-learn) (1.9.1)

# %%
rides_url = "C:\\Users\\ramya\\Downloads\\final_df_filtered.csv"
rides = pd.read_csv(rides_url)

# %%
# Load the police districts data (replace 'Police_Districts.csv' with your actual file)
police_districts_df = pd.read_csv("C:\\Users\\ramya\\Downloads\\Police_Stations_-_Map (1).csv")

# %%
rides
# Out:
#          Unnamed: 0  rideable_type           started_at             ended_at  \
# 0                 1   classic_bike  2023-01-01 00:02:06  2023-01-01 00:29:46
# 1                 2  electric_bike  2023-01-01 00:03:26  2023-01-01 00:07:23
# 2                 3   classic_bike  2023-01-01 00:04:07  2023-01-01 00:13:56
# 3                 4  electric_bike  2023-01-01 00:04:27  2023-01-01 00:16:52
# 4                 5   classic_bike  2023-01-01 00:04:54  2023-01-01 00:31:52
# ...             ...            ...                  ...                  ...
# 5570257     5719599  electric_bike  2023-12-31 23:53:47  2023-12-31 23:55:54
# 5570258     5719600  electric_bike  2023-12-31 23:55:28  2024-01-01 00:24:15
# 5570259     5719601  electric_bike  2023-12-31 23:56:28  2024-01-01 00:00:43
# 5570260     5719602  electric_bike  2023-12-31 23:57:01  2023-12-31 23:59:26
# 5570261     5719603  electric_bike  2023-12-31 23:58:55  2024-01-01 00:06:08
#
#                               start_station_name start_station_id  \
# 0                       Fairbanks Ct & Grand Ave     TA1305000003
# 1                       Sheridan Rd & Loyola Ave           RP-009
# 2                      Leavitt St & Lawrence Ave     TA1309000015
# 3                        Clark St & Montrose Ave     KA1503000022
# 4                         State St & Randolph St     TA1305000029
# ...                                          ...              ...
# 5570257                   Michigan Ave & Lake St     TA1305000011
# 5570258                     McClurg Ct & Ohio St     TA1306000029
# 5570259                   Michigan Ave & Lake St     TA1305000011
# 5570260                   Michigan Ave & Lake St     TA1305000011
# 5570261  Wolcott (Ravenswood) Ave & Montrose Ave     TA1307000144
#
#                    end_station_name end_station_id  start_lat  start_lng  ...  \
# 0              New St & Illinois St   TA1306000013  41.891847 -87.620580  ...
# 1          Sheridan Rd & Loyola Ave         RP-009  42.001139 -87.661256  ...
# 2              Broadway & Argyle St          13108  41.968885 -87.684001  ...
# 3           Clark St & Montrose Ave   KA1503000022  41.961545 -87.666189  ...
# 4        Indiana Ave & Roosevelt Rd         SL-005  41.884621 -87.627834  ...
# ...                             ...            ...        ...        ...  ...
# 5570257      Michigan Ave & Lake St   TA1305000011  41.886258 -87.624602  ...
# 5570258    Fairbanks Ct & Grand Ave   TA1305000003  41.892036 -87.616815  ...
# 5570259                         NaN            NaN  41.886146 -87.624730  ...
# 5570260                         NaN            NaN  41.886145 -87.624771  ...
# 5570261  Sheridan Rd & Montrose Ave   TA1307000107  41.961456 -87.676323  ...
#
#          started_at_month  started_at_hour    month        ride_time  \
# 0                 January                0  2023-01  0 days 00:27:40
# 1                 January                0  2023-01  0 days 00:03:57
# 2                 January                0  2023-01  0 days 00:09:49
# 3                 January                0  2023-01  0 days 00:12:25
# 4                 January                0  2023-01  0 days 00:26:58
# ...                   ...              ...      ...              ...
# 5570257          December               23  2023-12  0 days 00:02:07
# 5570258          December               23  2023-12  0 days 00:28:47
# 5570259          December               23  2023-12  0 days 00:04:15
# 5570260          December               23  2023-12  0 days 00:02:25
# 5570261          December               23  2023-12  0 days 00:07:13
#
#                  ride_time_1  rides_in_minutes  start_date avg_temp  \
# 0        2023-01-01 00:02:06              28.0  2023-01-01     41.0
# 1        2023-01-01 00:03:26               4.0  2023-01-01     41.0
# 2        2023-01-01 00:04:07              10.0  2023-01-01     41.0
# 3        2023-01-01 00:04:27              13.0  2023-01-01     41.0
# 4        2023-01-01 00:04:54              27.0  2023-01-01     41.0
# ...                      ...               ...         ...      ...
# 5570257  2023-12-31 23:53:47               3.0  2023-12-31     33.5
# 5570258  2023-12-31 23:55:28              29.0  2023-12-31     33.5
# 5570259  2023-12-31 23:56:28               5.0  2023-12-31     33.5
# 5570260  2023-12-31 23:57:01               3.0  2023-12-31     33.5
# 5570261  2023-12-31 23:58:55               8.0  2023-12-31     33.5
#
#                                                  start_end  season
# 0          Fairbanks Ct & Grand Ave / New St & Illinois St  Winter
# 1        Sheridan Rd & Loyola Ave / Sheridan Rd & Loyol...  Winter
# 2         Leavitt St & Lawrence Ave / Broadway & Argyle St  Winter
# 3        Clark St & Montrose Ave / Clark St & Montrose Ave  Winter
# 4        State St & Randolph St / Indiana Ave & Rooseve...  Winter
# ...                                                    ...     ...
# 5570257    Michigan Ave & Lake St / Michigan Ave & Lake St  Winter
# 5570258    McClurg Ct & Ohio St / Fairbanks Ct & Grand Ave  Winter
# 5570259                                                NaN  Winter
# 5570260                                                NaN  Winter
# 5570261  Wolcott (Ravenswood) Ave & Montrose Ave / Sher...  Winter
#
# [5570262 rows x 24 columns]

# %%
police_districts_df
# Out:
#         DISTRICT                   ADDRESS     CITY STATE    ZIP  \
# 0   Headquarters       3510 S Michigan Ave  Chicago    IL  60653
# 1             18        1160 N Larrabee St  Chicago    IL  60610
# 2             19          850 W Addison St  Chicago    IL  60613
# 3             20        5400 N Lincoln Ave  Chicago    IL  60625
# 4             22       1900 W Monterey Ave  Chicago    IL  60643
# 5             24           6464 N Clark St  Chicago    IL  60626
# 6             25          5555 W Grand Ave  Chicago    IL  60639
# 7              1           1718 S State St  Chicago    IL  60616
# 8              2      5101 S Wentworth Ave  Chicago    IL  60609
# 9              3  7040 S Cottage Grove Ave  Chicago    IL  60637
# 10             4           2255 E 103rd St  Chicago    IL  60617
# 11             5            727 E 111th St  Chicago    IL  60628
# 12             6         7808 S Halsted St  Chicago    IL  60620
# 13             7            1438 W 63rd St  Chicago    IL  60636
# 14             8            3420 W 63rd St  Chicago    IL  60629
# 15             9         3120 S Halsted St  Chicago    IL  60608
# 16            10          3315 W Ogden Ave  Chicago    IL  60623
# 17            11        3151 W Harrison St  Chicago    IL  60612
# 18            12  1412 S Blue Island Ave\n  Chicago    IL  60608
# 19            14     2150 N California Ave  Chicago    IL  60647
# 20            15         5701 W Madison St  Chicago    IL  60644
# 21            16      5151 N Milwaukee Ave  Chicago    IL  60630
# 22            17         4650 N Pulaski Rd  Chicago    IL  60630
#
#                                               WEBSITE  \
# 0                       http://home.chicagopolice.org
# 1   http://home.chicagopolice.org/community/distri...
# 2   http://home.chicagopolice.org/community/distri...
# 3   http://home.chicagopolice.org/community/distri...
# 4   http://home.chicagopolice.org/community/distri...
# 5   http://home.chicagopolice.org/community/distri...
# 6   http://home.chicagopolice.org/community/distri...
# 7   http://home.chicagopolice.org/community/distri...
# 8   http://home.chicagopolice.org/community/distri...
# 9   http://home.chicagopolice.org/community/distri...
# 10  http://home.chicagopolice.org/community/distri...
# 11  http://home.chicagopolice.org/community/distri...
# 12  http://home.chicagopolice.org/community/distri...
# 13  http://home.chicagopolice.org/community/distri...
# 14  http://home.chicagopolice.org/community/distri...
# 15  http://home.chicagopolice.org/community/distri...
# 16  http://home.chicagopolice.org/community/distri...
# 17  http://home.chicagopolice.org/community/distri...
# 18  http://home.chicagopolice.org/community/distri...
# 19  http://home.chicagopolice.org/community/distri...
# 20  http://home.chicagopolice.org/community/distri...
# 21  http://home.chicagopolice.org/community/distri...
# 22  http://home.chicagopolice.org/community/distri...
#
#                            LOCATION
# 0   (41.8307016873, -87.6233953459)
# 1   (41.9032416531, -87.6433521393)
# 2    (41.9474004564, -87.651512018)
# 3   (41.9795495131, -87.6928445094)
# 4   (41.6914347795, -87.6685203937)
# 5   (41.9997634842, -87.6713242922)
# 6    (41.9186088912, -87.765574479)
# 7    (41.8583725929, -87.627356171)
# 8   (41.8018110912, -87.6305601801)
# 9   (41.7664308925, -87.6057478606)
# 10  (41.7079332906, -87.5683491228)
# 11  (41.6927233639, -87.6045058667)
# 12  (41.7521368378, -87.6442289066)
# 13  (41.7796315359, -87.6608870173)
# 14   (41.778987189, -87.7088638153)
# 15  (41.8373944311, -87.6464077068)
# 16   (41.8566845327, -87.708381958)
# 17   (41.8735822883, -87.705488126)
# 18  (41.8629766244, -87.6569725149)
# 19  (41.9211033246, -87.6974518223)
# 20   (41.8800834614, -87.768199889)
# 21  (41.9740944511, -87.7661488432)
# 22   (41.9660534171, -87.728114561)

# %%
# Extract latitude and longitude from the 'LOCATION' column
police_districts_df['Latitude'] = police_districts_df['LOCATION'].apply(lambda x: str(x.split(",")[0].strip('(').strip('°').strip()))
police_districts_df['Longitude'] = police_districts_df['LOCATION'].apply(lambda x: str(x.split(",")[1].strip(')').strip('°').strip()))

# %%
police_districts_df
# Out:
#         DISTRICT                   ADDRESS     CITY STATE    ZIP  \
# 0   Headquarters       3510 S Michigan Ave  Chicago    IL  60653
# 1             18        1160 N Larrabee St  Chicago    IL  60610
# 2             19          850 W Addison St  Chicago    IL  60613
# 3             20        5400 N Lincoln Ave  Chicago    IL  60625
# 4             22       1900 W Monterey Ave  Chicago    IL  60643
# 5             24           6464 N Clark St  Chicago    IL  60626
# 6             25          5555 W Grand Ave  Chicago    IL  60639
# 7              1           1718 S State St  Chicago    IL  60616
# 8              2      5101 S Wentworth Ave  Chicago    IL  60609
# 9              3  7040 S Cottage Grove Ave  Chicago    IL  60637
# 10             4           2255 E 103rd St  Chicago    IL  60617
# 11             5            727 E 111th St  Chicago    IL  60628
# 12             6         7808 S Halsted St  Chicago    IL  60620
# 13             7            1438 W 63rd St  Chicago    IL  60636
# 14             8            3420 W 63rd St  Chicago    IL  60629
# 15             9         3120 S Halsted St  Chicago    IL  60608
# 16            10          3315 W Ogden Ave  Chicago    IL  60623
# 17            11        3151 W Harrison St  Chicago    IL  60612
# 18            12  1412 S Blue Island Ave\n  Chicago    IL  60608
# 19            14     2150 N California Ave  Chicago    IL  60647
# 20            15         5701 W Madison St  Chicago    IL  60644
# 21            16      5151 N Milwaukee Ave  Chicago    IL  60630
# 22            17         4650 N Pulaski Rd  Chicago    IL  60630
#
#                                               WEBSITE  \
# 0                       http://home.chicagopolice.org
# 1   http://home.chicagopolice.org/community/distri...
# 2   http://home.chicagopolice.org/community/distri...
# 3   http://home.chicagopolice.org/community/distri...
# 4   http://home.chicagopolice.org/community/distri...
# 5   http://home.chicagopolice.org/community/distri...
# 6   http://home.chicagopolice.org/community/distri...
# 7   http://home.chicagopolice.org/community/distri...
# 8   http://home.chicagopolice.org/community/distri...
# 9   http://home.chicagopolice.org/community/distri...
# 10  http://home.chicagopolice.org/community/distri...
# 11  http://home.chicagopolice.org/community/distri...
# 12  http://home.chicagopolice.org/community/distri...
# 13  http://home.chicagopolice.org/community/distri...
# 14  http://home.chicagopolice.org/community/distri...
# 15  http://home.chicagopolice.org/community/distri...
# 16  http://home.chicagopolice.org/community/distri...
# 17  http://home.chicagopolice.org/community/distri...
# 18  http://home.chicagopolice.org/community/distri...
# 19  http://home.chicagopolice.org/community/distri...
# 20  http://home.chicagopolice.org/community/distri...
# 21  http://home.chicagopolice.org/community/distri...
# 22  http://home.chicagopolice.org/community/distri...
#
#                            LOCATION       Latitude       Longitude
# 0   (41.8307016873, -87.6233953459)  41.8307016873  -87.6233953459
# 1   (41.9032416531, -87.6433521393)  41.9032416531  -87.6433521393
# 2    (41.9474004564, -87.651512018)  41.9474004564   -87.651512018
# 3   (41.9795495131, -87.6928445094)  41.9795495131  -87.6928445094
# 4   (41.6914347795, -87.6685203937)  41.6914347795  -87.6685203937
# 5   (41.9997634842, -87.6713242922)  41.9997634842  -87.6713242922
# 6    (41.9186088912, -87.765574479)  41.9186088912   -87.765574479
# 7    (41.8583725929, -87.627356171)  41.8583725929   -87.627356171
# 8   (41.8018110912, -87.6305601801)  41.8018110912  -87.6305601801
# 9   (41.7664308925, -87.6057478606)  41.7664308925  -87.6057478606
# 10  (41.7079332906, -87.5683491228)  41.7079332906  -87.5683491228
# 11  (41.6927233639, -87.6045058667)  41.6927233639  -87.6045058667
# 12  (41.7521368378, -87.6442289066)  41.7521368378  -87.6442289066
# 13  (41.7796315359, -87.6608870173)  41.7796315359  -87.6608870173
# 14   (41.778987189, -87.7088638153)   41.778987189  -87.7088638153
# 15  (41.8373944311, -87.6464077068)  41.8373944311  -87.6464077068
# 16   (41.8566845327, -87.708381958)  41.8566845327   -87.708381958
# 17   (41.8735822883, -87.705488126)  41.8735822883   -87.705488126
# 18  (41.8629766244, -87.6569725149)  41.8629766244  -87.6569725149
# 19  (41.9211033246, -87.6974518223)  41.9211033246  -87.6974518223
# 20   (41.8800834614, -87.768199889)  41.8800834614   -87.768199889
# 21  (41.9740944511, -87.7661488432)  41.9740944511  -87.7661488432
# 22   (41.9660534171, -87.728114561)  41.9660534171   -87.728114561

# %% [markdown]
# # Creating a district column in the rides DataFrame

# %%
# Create a GeoDataFrame for police districts
police_districts_gdf = gpd.GeoDataFrame(
    police_districts_df, 
    geometry=gpd.points_from_xy(police_districts_df['Longitude'], police_districts_df['Latitude']),
    crs="EPSG:4326"
)

# %%
# Create a GeoDataFrame for the ride start locations
rides_gdf = gpd.GeoDataFrame(
    rides, 
    geometry=gpd.points_from_xy(rides['start_lng'], rides['start_lat']),
    crs="EPSG:4326"
)

# %%
# Extract coordinates for NearestNeighbors
ride_coords = np.array(list(zip(rides_gdf.geometry.x, rides_gdf.geometry.y)))
district_coords = np.array(list(zip(police_districts_gdf.geometry.x, police_districts_gdf.geometry.y)))

# %%
# Use NearestNeighbors to find the nearest police district for each ride
nbrs = NearestNeighbors(n_neighbors=1, algorithm='ball_tree').fit(district_coords)
distances, indices = nbrs.kneighbors(ride_coords)

# %%
# Add the nearest district information to the rides dataframe
rides['district'] = police_districts_df.iloc[indices.flatten()]['DISTRICT'].values

# %%
rides
# Out:
#          Unnamed: 0  rideable_type           started_at             ended_at  \
# 0                 1   classic_bike  2023-01-01 00:02:06  2023-01-01 00:29:46
# 1                 2  electric_bike  2023-01-01 00:03:26  2023-01-01 00:07:23
# 2                 3   classic_bike  2023-01-01 00:04:07  2023-01-01 00:13:56
# 3                 4  electric_bike  2023-01-01 00:04:27  2023-01-01 00:16:52
# 4                 5   classic_bike  2023-01-01 00:04:54  2023-01-01 00:31:52
# ...             ...            ...                  ...                  ...
# 5570257     5719599  electric_bike  2023-12-31 23:53:47  2023-12-31 23:55:54
# 5570258     5719600  electric_bike  2023-12-31 23:55:28  2024-01-01 00:24:15
# 5570259     5719601  electric_bike  2023-12-31 23:56:28  2024-01-01 00:00:43
# 5570260     5719602  electric_bike  2023-12-31 23:57:01  2023-12-31 23:59:26
# 5570261     5719603  electric_bike  2023-12-31 23:58:55  2024-01-01 00:06:08
#
#                               start_station_name start_station_id  \
# 0                       Fairbanks Ct & Grand Ave     TA1305000003
# 1                       Sheridan Rd & Loyola Ave           RP-009
# 2                      Leavitt St & Lawrence Ave     TA1309000015
# 3                        Clark St & Montrose Ave     KA1503000022
# 4                         State St & Randolph St     TA1305000029
# ...                                          ...              ...
# 5570257                   Michigan Ave & Lake St     TA1305000011
# 5570258                     McClurg Ct & Ohio St     TA1306000029
# 5570259                   Michigan Ave & Lake St     TA1305000011
# 5570260                   Michigan Ave & Lake St     TA1305000011
# 5570261  Wolcott (Ravenswood) Ave & Montrose Ave     TA1307000144
#
#                    end_station_name end_station_id  start_lat  start_lng  ...  \
# 0              New St & Illinois St   TA1306000013  41.891847 -87.620580  ...
# 1          Sheridan Rd & Loyola Ave         RP-009  42.001139 -87.661256  ...
# 2              Broadway & Argyle St          13108  41.968885 -87.684001  ...
# 3           Clark St & Montrose Ave   KA1503000022  41.961545 -87.666189  ...
# 4        Indiana Ave & Roosevelt Rd         SL-005  41.884621 -87.627834  ...
# ...                             ...            ...        ...        ...  ...
# 5570257      Michigan Ave & Lake St   TA1305000011  41.886258 -87.624602  ...
# 5570258    Fairbanks Ct & Grand Ave   TA1305000003  41.892036 -87.616815  ...
# 5570259                         NaN            NaN  41.886146 -87.624730  ...
# 5570260                         NaN            NaN  41.886145 -87.624771  ...
# 5570261  Sheridan Rd & Montrose Ave   TA1307000107  41.961456 -87.676323  ...
#
#          started_at_hour    month        ride_time          ride_time_1  \
# 0                      0  2023-01  0 days 00:27:40  2023-01-01 00:02:06
# 1                      0  2023-01  0 days 00:03:57  2023-01-01 00:03:26
# 2                      0  2023-01  0 days 00:09:49  2023-01-01 00:04:07
# 3                      0  2023-01  0 days 00:12:25  2023-01-01 00:04:27
# 4                      0  2023-01  0 days 00:26:58  2023-01-01 00:04:54
# ...                  ...      ...              ...                  ...
# 5570257               23  2023-12  0 days 00:02:07  2023-12-31 23:53:47
# 5570258               23  2023-12  0 days 00:28:47  2023-12-31 23:55:28
# 5570259               23  2023-12  0 days 00:04:15  2023-12-31 23:56:28
# 5570260               23  2023-12  0 days 00:02:25  2023-12-31 23:57:01
# 5570261               23  2023-12  0 days 00:07:13  2023-12-31 23:58:55
#
#         rides_in_minutes  start_date avg_temp  \
# 0                   28.0  2023-01-01     41.0
# 1                    4.0  2023-01-01     41.0
# 2                   10.0  2023-01-01     41.0
# 3                   13.0  2023-01-01     41.0
# 4                   27.0  2023-01-01     41.0
# ...                  ...         ...      ...
# 5570257              3.0  2023-12-31     33.5
# 5570258             29.0  2023-12-31     33.5
# 5570259              5.0  2023-12-31     33.5
# 5570260              3.0  2023-12-31     33.5
# 5570261              8.0  2023-12-31     33.5
#
#                                                  start_end  season  district
# 0          Fairbanks Ct & Grand Ave / New St & Illinois St  Winter        18
# 1        Sheridan Rd & Loyola Ave / Sheridan Rd & Loyol...  Winter        24
# 2         Leavitt St & Lawrence Ave / Broadway & Argyle St  Winter        20
# 3        Clark St & Montrose Ave / Clark St & Montrose Ave  Winter        19
# 4        State St & Randolph St / Indiana Ave & Rooseve...  Winter        18
# ...                                                    ...     ...       ...
# 5570257    Michigan Ave & Lake St / Michigan Ave & Lake St  Winter        18
# 5570258    McClurg Ct & Ohio St / Fairbanks Ct & Grand Ave  Winter        18
# 5570259                                                NaN  Winter        18
# 5570260                                                NaN  Winter        18
# 5570261  Wolcott (Ravenswood) Ave & Montrose Ave / Sher...  Winter        20
#
# [5570262 rows x 25 columns]

# %%
# Checking how many rides are made from each district
rides['district'].value_counts()
# Out:
# 18              2004461
# 19              1091975
# 1                663504
# 12               455099
# 14               431073
# 3                212371
# 24               195168
# 20               154061
# Headquarters     113401
# 9                 48982
# 11                45911
# 17                43988
# 2                 23667
# 25                18682
# 10                15785
# 8                 13531
# 16                 8758
# 7                  6015
# 6                  5118
# 4                  5111
# 22                 5081
# 15                 4288
# 5                  4232
# Name: district, dtype: int64

# %%
#rides.to_csv("rides.csv")

# %% [markdown]
# # Importing Accidents Dataset

# %%
# Importing Accidents Dataset
accident_df = pd.read_csv("C:\\Users\\ramya\\Downloads\\accident_df_final.csv")
accident_df
# Out:
#       Unnamed: 0 PERSON_ID PERSON_TYPE  \
# 0              0  O1558342     BICYCLE
# 1              1  O1558486     BICYCLE
# 2              4  O1568916     BICYCLE
# 3              5  O1665711     BICYCLE
# 4              6  O1666065     BICYCLE
# ...          ...       ...         ...
# 1524        2011  O1742390     BICYCLE
# 1525        2012  O1743288     BICYCLE
# 1526        2013  O1744236     BICYCLE
# 1527        2014  O1757350     BICYCLE
# 1528        2015  O1773412     BICYCLE
#
#                                         CRASH_RECORD_ID        CRASH_DATE  \
# 0     b131d8e80f329ed77ed279badb1d3c60f06b108c7f63c7...   4/19/2023 13:45
# 1     bfce8b092f549a5785e9249d266bb88960d2dc54a08717...   4/19/2023 17:20
# 2     d313bbafece051a48e92c3de2fd8bbad529bec42fbd1db...     5/5/2023 8:08
# 3     a5393326d8f3a5c6a4cb2a26efdb4bfead74a915dce707...   9/21/2023 11:03
# 4     0bdb3396e7f9903245d1800e8b00c767742acdb5fe3507...   9/21/2023 18:30
# ...                                                 ...               ...
# 1524  3f4eafd97bff0aa3d356e81699fa4ce7e64f38cd5e77ad...  10/14/2023 22:00
# 1525  cffdc80acb3ba4708216d372e5c9b96b2e56bfcced8ea1...  12/20/2023 20:15
# 1526  826df47aebca62052e0820cc30ab3054a5026a63de2f48...  12/22/2023 18:15
# 1527  1e47752a6e5ef4bf88cad14768828e11e96de6f8364726...  11/29/2023 18:03
# 1528  8aef00211912d35808b709b3946f6c30783cc25ecd4d66...  12/18/2023 16:30
#
#          CITY STATE  ZIPCODE SEX   AGE  ...         EJECTION  \
# 0     CHICAGO    IL  60617.0   M  43.0  ...          UNKNOWN
# 1     CHICAGO    IL  60657.0   F   0.0  ...             NONE
# 2     CHICAGO    IL  60626.0   M  19.0  ...             NONE
# 3     CHICAGO    IL  60614.0   M  37.0  ...  TOTALLY EJECTED
# 4     CHICAGO    IL  60612.0   M  18.0  ...             NONE
# ...       ...   ...      ...  ..   ...  ...              ...
# 1524  CHICAGO    IL      NaN   F  19.0  ...              NaN
# 1525  CHICAGO    IL      NaN   F  13.0  ...             NONE
# 1526  CHICAGO    IL  60639.0   M  29.0  ...  TOTALLY EJECTED
# 1527  CHICAGO    IL  60605.0   M  26.0  ...          UNKNOWN
# 1528  CHICAGO    IL  60645.0   M  18.0  ...             NONE
#
#          INJURY_CLASSIFICATION              HOSPITAL  EMS_AGENCY  \
# 0      NO INDICATION OF INJURY                   NaN         NaN
# 1      NO INDICATION OF INJURY                   NaN         NaN
# 2     NONINCAPACITATING INJURY                   NaN         NaN
# 3     NONINCAPACITATING INJURY                   NaN         NaN
# 4      NO INDICATION OF INJURY                   NaN         NaN
# ...                        ...                   ...         ...
# 1524     REPORTED, NOT EVIDENT      STROGER HOSPITAL         NaN
# 1525  NONINCAPACITATING INJURY  HUMBOLDT PARK HEALTH  CFD AMB #3
# 1526  NONINCAPACITATING INJURY              ST MARYS         NaN
# 1527  NONINCAPACITATING INJURY      ILLINOIS MASONIC          62
# 1528  NONINCAPACITATING INJURY                   NaN         NaN
#
#      DRIVER_VISION PHYSICAL_CONDITION  \
# 0          UNKNOWN             NORMAL
# 1          UNKNOWN             NORMAL
# 2          UNKNOWN             NORMAL
# 3     NOT OBSCURED             NORMAL
# 4     NOT OBSCURED             NORMAL
# ...            ...                ...
# 1524  NOT OBSCURED             NORMAL
# 1525       UNKNOWN             NORMAL
# 1526  NOT OBSCURED             NORMAL
# 1527       UNKNOWN            UNKNOWN
# 1528       UNKNOWN            UNKNOWN
#
#                                         PEDPEDAL_ACTION  \
# 0              CROSSING - NO CONTROLS (AT INTERSECTION)
# 1                                          WITH TRAFFIC
# 2                                          TURNING LEFT
# 3                             CROSSING - AGAINST SIGNAL
# 4                                CROSSING - WITH SIGNAL
# ...                                                 ...
# 1524                             CROSSING - WITH SIGNAL
# 1525  CROSSING - CONTROLS PRESENT (NOT AT INTERSECTION)
# 1526                                          NO ACTION
# 1527                                       WITH TRAFFIC
# 1528                                       WITH TRAFFIC
#
#           PEDPEDAL_VISIBILITY PEDPEDAL_LOCATION        BAC_RESULT
# 0        CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 1     NO CONTRASTING CLOTHING           BIKEWAY  TEST NOT OFFERED
# 2     NO CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 3     NO CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 4     NO CONTRASTING CLOTHING      IN CROSSWALK  TEST NOT OFFERED
# ...                       ...               ...               ...
# 1524      REFLECTIVE MATERIAL           BIKEWAY  TEST NOT OFFERED
# 1525     CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 1526  NO CONTRASTING CLOTHING           BIKEWAY  TEST NOT OFFERED
# 1527  NO CONTRASTING CLOTHING         BIKE LANE  TEST NOT OFFERED
# 1528  NO CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
#
# [1529 rows x 21 columns]

# %%
# Dropping unnecessary columns
accident_df.drop(columns = ['Unnamed: 0'], inplace = True)
accident_df
# Out:
#      PERSON_ID PERSON_TYPE                                    CRASH_RECORD_ID  \
# 0     O1558342     BICYCLE  b131d8e80f329ed77ed279badb1d3c60f06b108c7f63c7...
# 1     O1558486     BICYCLE  bfce8b092f549a5785e9249d266bb88960d2dc54a08717...
# 2     O1568916     BICYCLE  d313bbafece051a48e92c3de2fd8bbad529bec42fbd1db...
# 3     O1665711     BICYCLE  a5393326d8f3a5c6a4cb2a26efdb4bfead74a915dce707...
# 4     O1666065     BICYCLE  0bdb3396e7f9903245d1800e8b00c767742acdb5fe3507...
# ...        ...         ...                                                ...
# 1524  O1742390     BICYCLE  3f4eafd97bff0aa3d356e81699fa4ce7e64f38cd5e77ad...
# 1525  O1743288     BICYCLE  cffdc80acb3ba4708216d372e5c9b96b2e56bfcced8ea1...
# 1526  O1744236     BICYCLE  826df47aebca62052e0820cc30ab3054a5026a63de2f48...
# 1527  O1757350     BICYCLE  1e47752a6e5ef4bf88cad14768828e11e96de6f8364726...
# 1528  O1773412     BICYCLE  8aef00211912d35808b709b3946f6c30783cc25ecd4d66...
#
#             CRASH_DATE     CITY STATE  ZIPCODE SEX   AGE  \
# 0      4/19/2023 13:45  CHICAGO    IL  60617.0   M  43.0
# 1      4/19/2023 17:20  CHICAGO    IL  60657.0   F   0.0
# 2        5/5/2023 8:08  CHICAGO    IL  60626.0   M  19.0
# 3      9/21/2023 11:03  CHICAGO    IL  60614.0   M  37.0
# 4      9/21/2023 18:30  CHICAGO    IL  60612.0   M  18.0
# ...                ...      ...   ...      ...  ..   ...
# 1524  10/14/2023 22:00  CHICAGO    IL      NaN   F  19.0
# 1525  12/20/2023 20:15  CHICAGO    IL      NaN   F  13.0
# 1526  12/22/2023 18:15  CHICAGO    IL  60639.0   M  29.0
# 1527  11/29/2023 18:03  CHICAGO    IL  60605.0   M  26.0
# 1528  12/18/2023 16:30  CHICAGO    IL  60645.0   M  18.0
#
#                                 SAFETY_EQUIPMENT         EJECTION  \
# 0     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)          UNKNOWN
# 1     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)             NONE
# 2                                HELMET NOT USED             NONE
# 3                                HELMET NOT USED  TOTALLY EJECTED
# 4     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)             NONE
# ...                                          ...              ...
# 1524  BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)              NaN
# 1525                             HELMET NOT USED             NONE
# 1526                             HELMET NOT USED  TOTALLY EJECTED
# 1527  BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)          UNKNOWN
# 1528                             HELMET NOT USED             NONE
#
#          INJURY_CLASSIFICATION              HOSPITAL  EMS_AGENCY  \
# 0      NO INDICATION OF INJURY                   NaN         NaN
# 1      NO INDICATION OF INJURY                   NaN         NaN
# 2     NONINCAPACITATING INJURY                   NaN         NaN
# 3     NONINCAPACITATING INJURY                   NaN         NaN
# 4      NO INDICATION OF INJURY                   NaN         NaN
# ...                        ...                   ...         ...
# 1524     REPORTED, NOT EVIDENT      STROGER HOSPITAL         NaN
# 1525  NONINCAPACITATING INJURY  HUMBOLDT PARK HEALTH  CFD AMB #3
# 1526  NONINCAPACITATING INJURY              ST MARYS         NaN
# 1527  NONINCAPACITATING INJURY      ILLINOIS MASONIC          62
# 1528  NONINCAPACITATING INJURY                   NaN         NaN
#
#      DRIVER_VISION PHYSICAL_CONDITION  \
# 0          UNKNOWN             NORMAL
# 1          UNKNOWN             NORMAL
# 2          UNKNOWN             NORMAL
# 3     NOT OBSCURED             NORMAL
# 4     NOT OBSCURED             NORMAL
# ...            ...                ...
# 1524  NOT OBSCURED             NORMAL
# 1525       UNKNOWN             NORMAL
# 1526  NOT OBSCURED             NORMAL
# 1527       UNKNOWN            UNKNOWN
# 1528       UNKNOWN            UNKNOWN
#
#                                         PEDPEDAL_ACTION  \
# 0              CROSSING - NO CONTROLS (AT INTERSECTION)
# 1                                          WITH TRAFFIC
# 2                                          TURNING LEFT
# 3                             CROSSING - AGAINST SIGNAL
# 4                                CROSSING - WITH SIGNAL
# ...                                                 ...
# 1524                             CROSSING - WITH SIGNAL
# 1525  CROSSING - CONTROLS PRESENT (NOT AT INTERSECTION)
# 1526                                          NO ACTION
# 1527                                       WITH TRAFFIC
# 1528                                       WITH TRAFFIC
#
#           PEDPEDAL_VISIBILITY PEDPEDAL_LOCATION        BAC_RESULT
# 0        CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 1     NO CONTRASTING CLOTHING           BIKEWAY  TEST NOT OFFERED
# 2     NO CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 3     NO CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 4     NO CONTRASTING CLOTHING      IN CROSSWALK  TEST NOT OFFERED
# ...                       ...               ...               ...
# 1524      REFLECTIVE MATERIAL           BIKEWAY  TEST NOT OFFERED
# 1525     CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 1526  NO CONTRASTING CLOTHING           BIKEWAY  TEST NOT OFFERED
# 1527  NO CONTRASTING CLOTHING         BIKE LANE  TEST NOT OFFERED
# 1528  NO CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
#
# [1529 rows x 20 columns]

# %%
accident_df['ZIPCODE'].value_counts().head(60)
# Out:
# 60647.0    76
# 60608.0    67
# 60618.0    66
# 60641.0    62
# 60640.0    62
# 60622.0    62
# 60625.0    60
# 60639.0    59
# 60626.0    41
# 60613.0    41
# 60657.0    35
# 60623.0    35
# 60614.0    34
# 60629.0    30
# 60634.0    29
# 60645.0    28
# 60609.0    28
# 60610.0    27
# 60616.0    26
# 60607.0    26
# 60630.0    25
# 60612.0    24
# 60632.0    24
# 60651.0    23
# 60660.0    22
# 60642.0    21
# 60624.0    19
# 60605.0    19
# 60617.0    18
# 60638.0    16
# 60659.0    16
# 60644.0    14
# 60611.0    14
# 60615.0    14
# 60621.0    12
# 60654.0    12
# 60619.0    11
# 60643.0    11
# 60620.0    10
# 60653.0    10
# 60649.0    10
# 60628.0     9
# 60636.0     8
# 60646.0     8
# 60631.0     8
# 60637.0     7
# 60661.0     7
# 60655.0     6
# 60656.0     4
# 60652.0     4
# 60601.0     4
# 60602.0     2
# 60603.0     2
# 60707.0     2
# 60606.0     2
# 60827.0     1
# 60045.0     1
# 60665.0     1
# 60064.0     1
# 66023.0     1
# Name: ZIPCODE, dtype: int64

# %%
# Checking for null values
accident_df.isna().sum()
# Out:
# PERSON_ID                  0
# PERSON_TYPE                0
# CRASH_RECORD_ID            0
# CRASH_DATE                 0
# CITY                       0
# STATE                      3
# ZIPCODE                  209
# SEX                       12
# AGE                       69
# SAFETY_EQUIPMENT           0
# EJECTION                  66
# INJURY_CLASSIFICATION      0
# HOSPITAL                 823
# EMS_AGENCY               919
# DRIVER_VISION             34
# PHYSICAL_CONDITION        29
# PEDPEDAL_ACTION            0
# PEDPEDAL_VISIBILITY        0
# PEDPEDAL_LOCATION          0
# BAC_RESULT                54
# dtype: int64

# %%
# Dropping the rows with null values in the column ZIPCODE
accident_df.dropna(subset = ['ZIPCODE'], inplace = True)

# %%
# Changing the data type of ZIPCODE into a string
accident_df['ZIPCODE'] = accident_df['ZIPCODE'].astype(str)

# %%
accident_df.dtypes
# Out:
# PERSON_ID                 object
# PERSON_TYPE               object
# CRASH_RECORD_ID           object
# CRASH_DATE                object
# CITY                      object
# STATE                     object
# ZIPCODE                   object
# SEX                       object
# AGE                      float64
# SAFETY_EQUIPMENT          object
# EJECTION                  object
# INJURY_CLASSIFICATION     object
# HOSPITAL                  object
# EMS_AGENCY                object
# DRIVER_VISION             object
# PHYSICAL_CONDITION        object
# PEDPEDAL_ACTION           object
# PEDPEDAL_VISIBILITY       object
# PEDPEDAL_LOCATION         object
# BAC_RESULT                object
# dtype: object

# %%
accident_df
# Out:
#      PERSON_ID PERSON_TYPE                                    CRASH_RECORD_ID  \
# 0     O1558342     BICYCLE  b131d8e80f329ed77ed279badb1d3c60f06b108c7f63c7...
# 1     O1558486     BICYCLE  bfce8b092f549a5785e9249d266bb88960d2dc54a08717...
# 2     O1568916     BICYCLE  d313bbafece051a48e92c3de2fd8bbad529bec42fbd1db...
# 3     O1665711     BICYCLE  a5393326d8f3a5c6a4cb2a26efdb4bfead74a915dce707...
# 4     O1666065     BICYCLE  0bdb3396e7f9903245d1800e8b00c767742acdb5fe3507...
# ...        ...         ...                                                ...
# 1522  O1732707     BICYCLE  a16946ff895b6bd97ea39f614d88f6e3c33398965f6fc7...
# 1523  O1732814     BICYCLE  09f44eb6e4805bfc2aceb87fc489436a0a009dac70e7ab...
# 1526  O1744236     BICYCLE  826df47aebca62052e0820cc30ab3054a5026a63de2f48...
# 1527  O1757350     BICYCLE  1e47752a6e5ef4bf88cad14768828e11e96de6f8364726...
# 1528  O1773412     BICYCLE  8aef00211912d35808b709b3946f6c30783cc25ecd4d66...
#
#             CRASH_DATE     CITY STATE  ZIPCODE SEX   AGE  \
# 0      4/19/2023 13:45  CHICAGO    IL  60617.0   M  43.0
# 1      4/19/2023 17:20  CHICAGO    IL  60657.0   F   0.0
# 2        5/5/2023 8:08  CHICAGO    IL  60626.0   M  19.0
# 3      9/21/2023 11:03  CHICAGO    IL  60614.0   M  37.0
# 4      9/21/2023 18:30  CHICAGO    IL  60612.0   M  18.0
# ...                ...      ...   ...      ...  ..   ...
# 1522  12/30/2023 16:44  CHICAGO    IL  60622.0   M  24.0
# 1523  12/30/2023 21:53  CHICAGO    IL  60613.0   M  32.0
# 1526  12/22/2023 18:15  CHICAGO    IL  60639.0   M  29.0
# 1527  11/29/2023 18:03  CHICAGO    IL  60605.0   M  26.0
# 1528  12/18/2023 16:30  CHICAGO    IL  60645.0   M  18.0
#
#                                 SAFETY_EQUIPMENT         EJECTION  \
# 0     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)          UNKNOWN
# 1     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)             NONE
# 2                                HELMET NOT USED             NONE
# 3                                HELMET NOT USED  TOTALLY EJECTED
# 4     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)             NONE
# ...                                          ...              ...
# 1522                             HELMET NOT USED             NONE
# 1523  BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)             NONE
# 1526                             HELMET NOT USED  TOTALLY EJECTED
# 1527  BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)          UNKNOWN
# 1528                             HELMET NOT USED             NONE
#
#          INJURY_CLASSIFICATION            HOSPITAL EMS_AGENCY DRIVER_VISION  \
# 0      NO INDICATION OF INJURY                 NaN        NaN       UNKNOWN
# 1      NO INDICATION OF INJURY                 NaN        NaN       UNKNOWN
# 2     NONINCAPACITATING INJURY                 NaN        NaN       UNKNOWN
# 3     NONINCAPACITATING INJURY                 NaN        NaN  NOT OBSCURED
# 4      NO INDICATION OF INJURY                 NaN        NaN  NOT OBSCURED
# ...                        ...                 ...        ...           ...
# 1522  NONINCAPACITATING INJURY  ST. MARYS HOSPITAL        NaN  NOT OBSCURED
# 1523  NONINCAPACITATING INJURY                 NaN        NaN  NOT OBSCURED
# 1526  NONINCAPACITATING INJURY            ST MARYS        NaN  NOT OBSCURED
# 1527  NONINCAPACITATING INJURY    ILLINOIS MASONIC         62       UNKNOWN
# 1528  NONINCAPACITATING INJURY                 NaN        NaN       UNKNOWN
#
#      PHYSICAL_CONDITION                           PEDPEDAL_ACTION  \
# 0                NORMAL  CROSSING - NO CONTROLS (AT INTERSECTION)
# 1                NORMAL                              WITH TRAFFIC
# 2                NORMAL                              TURNING LEFT
# 3                NORMAL                 CROSSING - AGAINST SIGNAL
# 4                NORMAL                    CROSSING - WITH SIGNAL
# ...                 ...                                       ...
# 1522             NORMAL                              WITH TRAFFIC
# 1523             NORMAL                                UNKNOWN/NA
# 1526             NORMAL                                 NO ACTION
# 1527            UNKNOWN                              WITH TRAFFIC
# 1528            UNKNOWN                              WITH TRAFFIC
#
#           PEDPEDAL_VISIBILITY PEDPEDAL_LOCATION        BAC_RESULT
# 0        CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 1     NO CONTRASTING CLOTHING           BIKEWAY  TEST NOT OFFERED
# 2     NO CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 3     NO CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 4     NO CONTRASTING CLOTHING      IN CROSSWALK  TEST NOT OFFERED
# ...                       ...               ...               ...
# 1522  NO CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 1523  NO CONTRASTING CLOTHING         BIKE LANE  TEST NOT OFFERED
# 1526  NO CONTRASTING CLOTHING           BIKEWAY  TEST NOT OFFERED
# 1527  NO CONTRASTING CLOTHING         BIKE LANE  TEST NOT OFFERED
# 1528  NO CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
#
# [1320 rows x 20 columns]

# %% [markdown]
# # Valid ZIPCODE IN CHICAGO

# %%
# List of ZIP codes in the dataset
zipcodes = ['60601'
    ,'60602'
    ,'60603'
    ,'60605'
    ,'60606'
    ,'60616'
    ,'60615'
    ,'60637'
    ,'60653'
    ,'60617'
    ,'60633'
    ,'60649'
    ,'60628'
    ,'60827'
    ,'60619'
    ,'60620'
    ,'60621'
    ,'60636'
    ,'60629'
    ,'60638'
    ,'60652'
    ,'60608'
    ,'60609'
    ,'60632'
    ,'60623'
    ,'60624'
    ,'60607'
    ,'60612'
    ,'60661'
    ,'60622'
    ,'60642'
    ,'60647'
    ,'60644'
    ,'60630'
    ,'60631'
    ,'60634'
    ,'60641'
    ,'60646'
    ,'60656'
    ,'60707'
    ,'60618'
    ,'60610'
    ,'60611'
    ,'60614'
    ,'60654'
    ,'60613'
    ,'60657'
    ,'60625'
    ,'60640'
    ,'60659'
    ,'60643'
    ,'60655'
    ,'60626'
    ,'60645'
    ,'60660'
    ,'60639'
    ,'60651'
    ,'60045'
    ,'60064'
    ,'60123'
    ,'60061'
    ,'66023'
    ,'60665']


# List of valid Chicago ZIP codes
chicago_zipcodes = [
    "60601", "60602", "60603", "60604", "60605", "60606", "60607", "60608", "60609", "60610",
    "60611", "60612", "60613", "60614", "60615", "60616", "60617", "60618", "60619", "60620",
    "60621", "60622", "60623", "60624", "60625", "60626", "60628", "60629", "60630", "60631",
    "60632", "60633", "60634", "60636", "60637", "60638", "60639", "60640", "60641", "60643",
    "60644", "60645", "60646", "60647", "60649", "60651", "60652", "60653", "60654", "60655",
    "60656", "60657", "60659", "60660", "60661", "60664", "60666", "60680", "60681", "60690",
    "60691"
]


# Filter out ZIP codes that are not in Chicago
valid_zipcodes = [zipcode for zipcode in zipcodes if zipcode in chicago_zipcodes]

print("Valid ZIP codes for Chicago:")
print(valid_zipcodes)
# Out:
# Valid ZIP codes for Chicago:
# ['60601', '60602', '60603', '60605', '60606', '60616', '60615', '60637', '60653', '60617', '60633', '60649', '60628', '60619', '60620', '60621', '60636', '60629', '60638', '60652', '60608', '60609', '60632', '60623', '60624', '60607', '60612', '60661', '60622', '60647', '60644', '60630', '60631', '60634', '60641', '60646', '60656', '60618', '60610', '60611', '60614', '60654', '60613', '60657', '60625', '60640', '60659', '60643', '60655', '60626', '60645', '60660', '60639', '60651']

# %%
# Checking the ZIPCODE types to make sure they match
print(accident_df['ZIPCODE'].dtype)
print(type(valid_zipcodes[0]))
# Out:
# object
# <class 'str'>

# %%
# Convert the ZIPCODE column to string type explicitly
accident_df['ZIPCODE'] = accident_df['ZIPCODE'].astype('string')

# %%
# Ensure valid_zipcodes are also strings
valid_zipcodes = pd.Series(valid_zipcodes, dtype='string')

# %%
# Removing the ".0" from the ZIPCODE values in the DataFrame accident_df 
accident_df['ZIPCODE'] = accident_df['ZIPCODE'].str.split('.').str[0]

# %%
# Creating a dataframe with only including valid zipcodes 
filtered_accident_df = accident_df[accident_df['ZIPCODE'].isin(valid_zipcodes)]
filtered_accident_df
# Out:
#      PERSON_ID PERSON_TYPE                                    CRASH_RECORD_ID  \
# 0     O1558342     BICYCLE  b131d8e80f329ed77ed279badb1d3c60f06b108c7f63c7...
# 1     O1558486     BICYCLE  bfce8b092f549a5785e9249d266bb88960d2dc54a08717...
# 2     O1568916     BICYCLE  d313bbafece051a48e92c3de2fd8bbad529bec42fbd1db...
# 3     O1665711     BICYCLE  a5393326d8f3a5c6a4cb2a26efdb4bfead74a915dce707...
# 4     O1666065     BICYCLE  0bdb3396e7f9903245d1800e8b00c767742acdb5fe3507...
# ...        ...         ...                                                ...
# 1522  O1732707     BICYCLE  a16946ff895b6bd97ea39f614d88f6e3c33398965f6fc7...
# 1523  O1732814     BICYCLE  09f44eb6e4805bfc2aceb87fc489436a0a009dac70e7ab...
# 1526  O1744236     BICYCLE  826df47aebca62052e0820cc30ab3054a5026a63de2f48...
# 1527  O1757350     BICYCLE  1e47752a6e5ef4bf88cad14768828e11e96de6f8364726...
# 1528  O1773412     BICYCLE  8aef00211912d35808b709b3946f6c30783cc25ecd4d66...
#
#             CRASH_DATE     CITY STATE ZIPCODE SEX   AGE  \
# 0      4/19/2023 13:45  CHICAGO    IL   60617   M  43.0
# 1      4/19/2023 17:20  CHICAGO    IL   60657   F   0.0
# 2        5/5/2023 8:08  CHICAGO    IL   60626   M  19.0
# 3      9/21/2023 11:03  CHICAGO    IL   60614   M  37.0
# 4      9/21/2023 18:30  CHICAGO    IL   60612   M  18.0
# ...                ...      ...   ...     ...  ..   ...
# 1522  12/30/2023 16:44  CHICAGO    IL   60622   M  24.0
# 1523  12/30/2023 21:53  CHICAGO    IL   60613   M  32.0
# 1526  12/22/2023 18:15  CHICAGO    IL   60639   M  29.0
# 1527  11/29/2023 18:03  CHICAGO    IL   60605   M  26.0
# 1528  12/18/2023 16:30  CHICAGO    IL   60645   M  18.0
#
#                                 SAFETY_EQUIPMENT         EJECTION  \
# 0     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)          UNKNOWN
# 1     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)             NONE
# 2                                HELMET NOT USED             NONE
# 3                                HELMET NOT USED  TOTALLY EJECTED
# 4     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)             NONE
# ...                                          ...              ...
# 1522                             HELMET NOT USED             NONE
# 1523  BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)             NONE
# 1526                             HELMET NOT USED  TOTALLY EJECTED
# 1527  BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)          UNKNOWN
# 1528                             HELMET NOT USED             NONE
#
#          INJURY_CLASSIFICATION            HOSPITAL EMS_AGENCY DRIVER_VISION  \
# 0      NO INDICATION OF INJURY                 NaN        NaN       UNKNOWN
# 1      NO INDICATION OF INJURY                 NaN        NaN       UNKNOWN
# 2     NONINCAPACITATING INJURY                 NaN        NaN       UNKNOWN
# 3     NONINCAPACITATING INJURY                 NaN        NaN  NOT OBSCURED
# 4      NO INDICATION OF INJURY                 NaN        NaN  NOT OBSCURED
# ...                        ...                 ...        ...           ...
# 1522  NONINCAPACITATING INJURY  ST. MARYS HOSPITAL        NaN  NOT OBSCURED
# 1523  NONINCAPACITATING INJURY                 NaN        NaN  NOT OBSCURED
# 1526  NONINCAPACITATING INJURY            ST MARYS        NaN  NOT OBSCURED
# 1527  NONINCAPACITATING INJURY    ILLINOIS MASONIC         62       UNKNOWN
# 1528  NONINCAPACITATING INJURY                 NaN        NaN       UNKNOWN
#
#      PHYSICAL_CONDITION                           PEDPEDAL_ACTION  \
# 0                NORMAL  CROSSING - NO CONTROLS (AT INTERSECTION)
# 1                NORMAL                              WITH TRAFFIC
# 2                NORMAL                              TURNING LEFT
# 3                NORMAL                 CROSSING - AGAINST SIGNAL
# 4                NORMAL                    CROSSING - WITH SIGNAL
# ...                 ...                                       ...
# 1522             NORMAL                              WITH TRAFFIC
# 1523             NORMAL                                UNKNOWN/NA
# 1526             NORMAL                                 NO ACTION
# 1527            UNKNOWN                              WITH TRAFFIC
# 1528            UNKNOWN                              WITH TRAFFIC
#
#           PEDPEDAL_VISIBILITY PEDPEDAL_LOCATION        BAC_RESULT
# 0        CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 1     NO CONTRASTING CLOTHING           BIKEWAY  TEST NOT OFFERED
# 2     NO CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 3     NO CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 4     NO CONTRASTING CLOTHING      IN CROSSWALK  TEST NOT OFFERED
# ...                       ...               ...               ...
# 1522  NO CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 1523  NO CONTRASTING CLOTHING         BIKE LANE  TEST NOT OFFERED
# 1526  NO CONTRASTING CLOTHING           BIKEWAY  TEST NOT OFFERED
# 1527  NO CONTRASTING CLOTHING         BIKE LANE  TEST NOT OFFERED
# 1528  NO CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
#
# [1290 rows x 20 columns]

# %%
filtered_accident_df['ZIPCODE']
# Out:
# 0       60617
# 1       60657
# 2       60626
# 3       60614
# 4       60612
#         ...
# 1522    60622
# 1523    60613
# 1526    60639
# 1527    60605
# 1528    60645
# Name: ZIPCODE, Length: 1290, dtype: object

# %%
distinct_zipcodes = filtered_accident_df['ZIPCODE'].unique().tolist()
distinct_zipcodes
# Out:
# ['60617',
#  '60657',
#  '60626',
#  '60614',
#  '60612',
#  '60645',
#  '60616',
#  '60615',
#  '60618',
#  '60623',
#  '60629',
#  '60659',
#  '60640',
#  '60608',
#  '60634',
#  '60647',
#  '60610',
#  '60622',
#  '60639',
#  '60641',
#  '60637',
#  '60643',
#  '60651',
#  '60607',
#  '60632',
#  '60655',
#  '60605',
#  '60660',
#  '60630',
#  '60644',
#  '60624',
#  '60646',
#  '60609',
#  '60638',
#  '60625',
#  '60621',
#  '60619',
#  '60654',
#  '60613',
#  '60661',
#  '60620',
#  '60653',
#  '60656',
#  '60649',
#  '60628',
#  '60631',
#  '60602',
#  '60611',
#  '60652',
#  '60603',
#  '60636',
#  '60601',
#  '60606',
#  '60633']

# %%
filtered_accident_df
# Out:
#      PERSON_ID PERSON_TYPE                                    CRASH_RECORD_ID  \
# 0     O1558342     BICYCLE  b131d8e80f329ed77ed279badb1d3c60f06b108c7f63c7...
# 1     O1558486     BICYCLE  bfce8b092f549a5785e9249d266bb88960d2dc54a08717...
# 2     O1568916     BICYCLE  d313bbafece051a48e92c3de2fd8bbad529bec42fbd1db...
# 3     O1665711     BICYCLE  a5393326d8f3a5c6a4cb2a26efdb4bfead74a915dce707...
# 4     O1666065     BICYCLE  0bdb3396e7f9903245d1800e8b00c767742acdb5fe3507...
# ...        ...         ...                                                ...
# 1522  O1732707     BICYCLE  a16946ff895b6bd97ea39f614d88f6e3c33398965f6fc7...
# 1523  O1732814     BICYCLE  09f44eb6e4805bfc2aceb87fc489436a0a009dac70e7ab...
# 1526  O1744236     BICYCLE  826df47aebca62052e0820cc30ab3054a5026a63de2f48...
# 1527  O1757350     BICYCLE  1e47752a6e5ef4bf88cad14768828e11e96de6f8364726...
# 1528  O1773412     BICYCLE  8aef00211912d35808b709b3946f6c30783cc25ecd4d66...
#
#             CRASH_DATE     CITY STATE ZIPCODE SEX   AGE  \
# 0      4/19/2023 13:45  CHICAGO    IL   60617   M  43.0
# 1      4/19/2023 17:20  CHICAGO    IL   60657   F   0.0
# 2        5/5/2023 8:08  CHICAGO    IL   60626   M  19.0
# 3      9/21/2023 11:03  CHICAGO    IL   60614   M  37.0
# 4      9/21/2023 18:30  CHICAGO    IL   60612   M  18.0
# ...                ...      ...   ...     ...  ..   ...
# 1522  12/30/2023 16:44  CHICAGO    IL   60622   M  24.0
# 1523  12/30/2023 21:53  CHICAGO    IL   60613   M  32.0
# 1526  12/22/2023 18:15  CHICAGO    IL   60639   M  29.0
# 1527  11/29/2023 18:03  CHICAGO    IL   60605   M  26.0
# 1528  12/18/2023 16:30  CHICAGO    IL   60645   M  18.0
#
#                                 SAFETY_EQUIPMENT         EJECTION  \
# 0     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)          UNKNOWN
# 1     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)             NONE
# 2                                HELMET NOT USED             NONE
# 3                                HELMET NOT USED  TOTALLY EJECTED
# 4     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)             NONE
# ...                                          ...              ...
# 1522                             HELMET NOT USED             NONE
# 1523  BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)             NONE
# 1526                             HELMET NOT USED  TOTALLY EJECTED
# 1527  BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)          UNKNOWN
# 1528                             HELMET NOT USED             NONE
#
#          INJURY_CLASSIFICATION            HOSPITAL EMS_AGENCY DRIVER_VISION  \
# 0      NO INDICATION OF INJURY                 NaN        NaN       UNKNOWN
# 1      NO INDICATION OF INJURY                 NaN        NaN       UNKNOWN
# 2     NONINCAPACITATING INJURY                 NaN        NaN       UNKNOWN
# 3     NONINCAPACITATING INJURY                 NaN        NaN  NOT OBSCURED
# 4      NO INDICATION OF INJURY                 NaN        NaN  NOT OBSCURED
# ...                        ...                 ...        ...           ...
# 1522  NONINCAPACITATING INJURY  ST. MARYS HOSPITAL        NaN  NOT OBSCURED
# 1523  NONINCAPACITATING INJURY                 NaN        NaN  NOT OBSCURED
# 1526  NONINCAPACITATING INJURY            ST MARYS        NaN  NOT OBSCURED
# 1527  NONINCAPACITATING INJURY    ILLINOIS MASONIC         62       UNKNOWN
# 1528  NONINCAPACITATING INJURY                 NaN        NaN       UNKNOWN
#
#      PHYSICAL_CONDITION                           PEDPEDAL_ACTION  \
# 0                NORMAL  CROSSING - NO CONTROLS (AT INTERSECTION)
# 1                NORMAL                              WITH TRAFFIC
# 2                NORMAL                              TURNING LEFT
# 3                NORMAL                 CROSSING - AGAINST SIGNAL
# 4                NORMAL                    CROSSING - WITH SIGNAL
# ...                 ...                                       ...
# 1522             NORMAL                              WITH TRAFFIC
# 1523             NORMAL                                UNKNOWN/NA
# 1526             NORMAL                                 NO ACTION
# 1527            UNKNOWN                              WITH TRAFFIC
# 1528            UNKNOWN                              WITH TRAFFIC
#
#           PEDPEDAL_VISIBILITY PEDPEDAL_LOCATION        BAC_RESULT
# 0        CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 1     NO CONTRASTING CLOTHING           BIKEWAY  TEST NOT OFFERED
# 2     NO CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 3     NO CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 4     NO CONTRASTING CLOTHING      IN CROSSWALK  TEST NOT OFFERED
# ...                       ...               ...               ...
# 1522  NO CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
# 1523  NO CONTRASTING CLOTHING         BIKE LANE  TEST NOT OFFERED
# 1526  NO CONTRASTING CLOTHING           BIKEWAY  TEST NOT OFFERED
# 1527  NO CONTRASTING CLOTHING         BIKE LANE  TEST NOT OFFERED
# 1528  NO CONTRASTING CLOTHING        IN ROADWAY  TEST NOT OFFERED
#
# [1290 rows x 20 columns]

# %% [markdown]
# # Importing the coordinates of each of chicago zipcodes'

# %%
import pandas as pd
from geopy.geocoders import Nominatim

# Initialize a geocoder
geolocator = Nominatim(user_agent="my_geocoder")

# Function to get centroid coordinates of a ZIP code
def get_zip_centroid(zipcode):
    location = geolocator.geocode({"postalcode": zipcode})
    if location:
        return zipcode, location.latitude, location.longitude
    else:
        return None

# Function to create a DataFrame with ZIP code, Latitude, and Longitude columns
def create_zipcode_dataframe(zipcodes):
    data = []
    for zipcode in zipcodes:
        centroid = get_zip_centroid(zipcode)
        if centroid:
            data.append(centroid)
    df = pd.DataFrame(data, columns=["ZIPCODE", "Latitude", "Longitude"])
    return df


zipcode_df = create_zipcode_dataframe(distinct_zipcodes)
print(zipcode_df)
# Out:
#    ZIPCODE   Latitude  Longitude
# 0    60617  41.720556 -87.555480
# 1    60657  41.939384 -87.655629
# 2    60626  42.012763 -87.668274
# 3    60614  41.922401 -87.651560
# 4    60612  41.879027 -87.686180
# 5    60645  42.009352 -87.697004
# 6    60616  41.846954 -87.632215
# 7    60615  41.801461 -87.595483
# 8    60618  41.945181 -87.700827
# 9    60623  41.849989 -87.718160
# 10   60629  41.781218 -87.712077
# 11   60659  41.987316 -87.706026
# 12   60640  49.667218   3.040818
# 13   60608  58.485226  26.380486
# 14   60634  41.946370 -87.809685
# 15   60647  41.919326 -87.698748
# 16   60610  49.357589   2.804158
# 17   60622  41.901307 -87.674636
# 18   60639  41.919423 -87.754785
# 19   60641  41.946458 -87.741885
# 20   60637  41.786961 -87.597310
# 21   60643  41.692922 -87.661216
# 22   60651  41.900689 -87.744463
# 23   60607  41.876931 -87.651322
# 24   60632  41.810924 -87.704617
# 25   60655  41.694868 -87.702143
# 26   60605  58.459688  26.364155
# 27   60660  49.273159   2.366473
# 28   60630  41.965931 -87.761834
# 29   60644  41.875840 -87.763857
# 30   60624  41.878172 -87.720466
# 31   60646  41.999728 -87.764916
# 32   60609  41.813682 -87.645758
# 33   60638  41.787851 -87.770442
# 34   60625  41.967188 -87.700468
# 35   60621  41.778114 -87.637951
# 36   60619  41.736759 -87.600706
# 37   60654  41.891464 -87.633246
# 38   60613  41.952681 -87.658991
# 39   60661  41.886119 -87.646816
# 40   60620  49.141145   2.947032
# 41   60653  41.818560 -87.610431
# 42   60656  41.971424 -87.833260
# 43   60649  41.761649 -87.571791
# 44   60628  41.691124 -87.622209
# 45   60631  41.998791 -87.815328
# 46   60602  41.883010 -87.629055
# 47   60611  41.895126 -87.622606
# 48   60652  41.744762 -87.712971
# 49   60603   9.472344 -84.105344
# 50   60636  41.776259 -87.662720
# 51   60601   9.422340 -84.154456
# 52   60606  58.510486  26.418544
# 53   60633  41.655863 -87.546662

# %%
#zipcode_df.to_csv("zipcode_df.csv")

# %%
#zipcode_df = pd.read_csv("C:\\Users\\ramya\\Downloads\\zipcode_df.csv")

# %%
# Chnging the datatypes 
zipcode_df['ZIPCODE'] = zipcode_df['ZIPCODE'].astype(str)

# %%
zipcode_df.dtypes
# Out:
# ZIPCODE       object
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
filtered_accident_df.dtypes
# Out:
# PERSON_ID                 object
# PERSON_TYPE               object
# CRASH_RECORD_ID           object
# CRASH_DATE                object
# CITY                      object
# STATE                     object
# ZIPCODE                   object
# SEX                       object
# AGE                      float64
# SAFETY_EQUIPMENT          object
# EJECTION                  object
# INJURY_CLASSIFICATION     object
# HOSPITAL                  object
# EMS_AGENCY                object
# DRIVER_VISION             object
# PHYSICAL_CONDITION        object
# PEDPEDAL_ACTION           object
# PEDPEDAL_VISIBILITY       object
# PEDPEDAL_LOCATION         object
# BAC_RESULT                object
# dtype: object

# %%
filtered_accident_df = filtered_accident_df.merge(zipcode_df, left_on = "ZIPCODE", right_on = "ZIPCODE", how = 'left')
filtered_accident_df
# Out:
#      PERSON_ID PERSON_TYPE                                    CRASH_RECORD_ID  \
# 0     O1558342     BICYCLE  b131d8e80f329ed77ed279badb1d3c60f06b108c7f63c7...
# 1     O1558486     BICYCLE  bfce8b092f549a5785e9249d266bb88960d2dc54a08717...
# 2     O1568916     BICYCLE  d313bbafece051a48e92c3de2fd8bbad529bec42fbd1db...
# 3     O1665711     BICYCLE  a5393326d8f3a5c6a4cb2a26efdb4bfead74a915dce707...
# 4     O1666065     BICYCLE  0bdb3396e7f9903245d1800e8b00c767742acdb5fe3507...
# ...        ...         ...                                                ...
# 1285  O1732707     BICYCLE  a16946ff895b6bd97ea39f614d88f6e3c33398965f6fc7...
# 1286  O1732814     BICYCLE  09f44eb6e4805bfc2aceb87fc489436a0a009dac70e7ab...
# 1287  O1744236     BICYCLE  826df47aebca62052e0820cc30ab3054a5026a63de2f48...
# 1288  O1757350     BICYCLE  1e47752a6e5ef4bf88cad14768828e11e96de6f8364726...
# 1289  O1773412     BICYCLE  8aef00211912d35808b709b3946f6c30783cc25ecd4d66...
#
#             CRASH_DATE     CITY STATE ZIPCODE SEX   AGE  \
# 0      4/19/2023 13:45  CHICAGO    IL   60617   M  43.0
# 1      4/19/2023 17:20  CHICAGO    IL   60657   F   0.0
# 2        5/5/2023 8:08  CHICAGO    IL   60626   M  19.0
# 3      9/21/2023 11:03  CHICAGO    IL   60614   M  37.0
# 4      9/21/2023 18:30  CHICAGO    IL   60612   M  18.0
# ...                ...      ...   ...     ...  ..   ...
# 1285  12/30/2023 16:44  CHICAGO    IL   60622   M  24.0
# 1286  12/30/2023 21:53  CHICAGO    IL   60613   M  32.0
# 1287  12/22/2023 18:15  CHICAGO    IL   60639   M  29.0
# 1288  11/29/2023 18:03  CHICAGO    IL   60605   M  26.0
# 1289  12/18/2023 16:30  CHICAGO    IL   60645   M  18.0
#
#                                 SAFETY_EQUIPMENT  ...            HOSPITAL  \
# 0     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...                 NaN
# 1     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...                 NaN
# 2                                HELMET NOT USED  ...                 NaN
# 3                                HELMET NOT USED  ...                 NaN
# 4     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...                 NaN
# ...                                          ...  ...                 ...
# 1285                             HELMET NOT USED  ...  ST. MARYS HOSPITAL
# 1286  BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...                 NaN
# 1287                             HELMET NOT USED  ...            ST MARYS
# 1288  BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...    ILLINOIS MASONIC
# 1289                             HELMET NOT USED  ...                 NaN
#
#      EMS_AGENCY DRIVER_VISION PHYSICAL_CONDITION  \
# 0           NaN       UNKNOWN             NORMAL
# 1           NaN       UNKNOWN             NORMAL
# 2           NaN       UNKNOWN             NORMAL
# 3           NaN  NOT OBSCURED             NORMAL
# 4           NaN  NOT OBSCURED             NORMAL
# ...         ...           ...                ...
# 1285        NaN  NOT OBSCURED             NORMAL
# 1286        NaN  NOT OBSCURED             NORMAL
# 1287        NaN  NOT OBSCURED             NORMAL
# 1288         62       UNKNOWN            UNKNOWN
# 1289        NaN       UNKNOWN            UNKNOWN
#
#                                PEDPEDAL_ACTION      PEDPEDAL_VISIBILITY  \
# 0     CROSSING - NO CONTROLS (AT INTERSECTION)     CONTRASTING CLOTHING
# 1                                 WITH TRAFFIC  NO CONTRASTING CLOTHING
# 2                                 TURNING LEFT  NO CONTRASTING CLOTHING
# 3                    CROSSING - AGAINST SIGNAL  NO CONTRASTING CLOTHING
# 4                       CROSSING - WITH SIGNAL  NO CONTRASTING CLOTHING
# ...                                        ...                      ...
# 1285                              WITH TRAFFIC  NO CONTRASTING CLOTHING
# 1286                                UNKNOWN/NA  NO CONTRASTING CLOTHING
# 1287                                 NO ACTION  NO CONTRASTING CLOTHING
# 1288                              WITH TRAFFIC  NO CONTRASTING CLOTHING
# 1289                              WITH TRAFFIC  NO CONTRASTING CLOTHING
#
#      PEDPEDAL_LOCATION        BAC_RESULT   Latitude  Longitude
# 0           IN ROADWAY  TEST NOT OFFERED  41.720556 -87.555480
# 1              BIKEWAY  TEST NOT OFFERED  41.939384 -87.655629
# 2           IN ROADWAY  TEST NOT OFFERED  42.012763 -87.668274
# 3           IN ROADWAY  TEST NOT OFFERED  41.922401 -87.651560
# 4         IN CROSSWALK  TEST NOT OFFERED  41.879027 -87.686180
# ...                ...               ...        ...        ...
# 1285        IN ROADWAY  TEST NOT OFFERED  41.901307 -87.674636
# 1286         BIKE LANE  TEST NOT OFFERED  41.952681 -87.658991
# 1287           BIKEWAY  TEST NOT OFFERED  41.919423 -87.754785
# 1288         BIKE LANE  TEST NOT OFFERED  58.459688  26.364155
# 1289        IN ROADWAY  TEST NOT OFFERED  42.009352 -87.697004
#
# [1290 rows x 22 columns]

# %% [markdown]
# # Adding a district column to the filtered_accidents_df

# %%
police_districts_df['Latitude'] = police_districts_df['Latitude'].astype(str)
police_districts_df['Longitude'] = police_districts_df['Longitude'].astype(str)

# %%
zipcode_df['ZIPCODE'] = zipcode_df['ZIPCODE'].astype(str)

# %%
police_districts_df
# Out:
#         DISTRICT                   ADDRESS     CITY STATE    ZIP  \
# 0   Headquarters       3510 S Michigan Ave  Chicago    IL  60653
# 1             18        1160 N Larrabee St  Chicago    IL  60610
# 2             19          850 W Addison St  Chicago    IL  60613
# 3             20        5400 N Lincoln Ave  Chicago    IL  60625
# 4             22       1900 W Monterey Ave  Chicago    IL  60643
# 5             24           6464 N Clark St  Chicago    IL  60626
# 6             25          5555 W Grand Ave  Chicago    IL  60639
# 7              1           1718 S State St  Chicago    IL  60616
# 8              2      5101 S Wentworth Ave  Chicago    IL  60609
# 9              3  7040 S Cottage Grove Ave  Chicago    IL  60637
# 10             4           2255 E 103rd St  Chicago    IL  60617
# 11             5            727 E 111th St  Chicago    IL  60628
# 12             6         7808 S Halsted St  Chicago    IL  60620
# 13             7            1438 W 63rd St  Chicago    IL  60636
# 14             8            3420 W 63rd St  Chicago    IL  60629
# 15             9         3120 S Halsted St  Chicago    IL  60608
# 16            10          3315 W Ogden Ave  Chicago    IL  60623
# 17            11        3151 W Harrison St  Chicago    IL  60612
# 18            12  1412 S Blue Island Ave\n  Chicago    IL  60608
# 19            14     2150 N California Ave  Chicago    IL  60647
# 20            15         5701 W Madison St  Chicago    IL  60644
# 21            16      5151 N Milwaukee Ave  Chicago    IL  60630
# 22            17         4650 N Pulaski Rd  Chicago    IL  60630
#
#                                               WEBSITE  \
# 0                       http://home.chicagopolice.org
# 1   http://home.chicagopolice.org/community/distri...
# 2   http://home.chicagopolice.org/community/distri...
# 3   http://home.chicagopolice.org/community/distri...
# 4   http://home.chicagopolice.org/community/distri...
# 5   http://home.chicagopolice.org/community/distri...
# 6   http://home.chicagopolice.org/community/distri...
# 7   http://home.chicagopolice.org/community/distri...
# 8   http://home.chicagopolice.org/community/distri...
# 9   http://home.chicagopolice.org/community/distri...
# 10  http://home.chicagopolice.org/community/distri...
# 11  http://home.chicagopolice.org/community/distri...
# 12  http://home.chicagopolice.org/community/distri...
# 13  http://home.chicagopolice.org/community/distri...
# 14  http://home.chicagopolice.org/community/distri...
# 15  http://home.chicagopolice.org/community/distri...
# 16  http://home.chicagopolice.org/community/distri...
# 17  http://home.chicagopolice.org/community/distri...
# 18  http://home.chicagopolice.org/community/distri...
# 19  http://home.chicagopolice.org/community/distri...
# 20  http://home.chicagopolice.org/community/distri...
# 21  http://home.chicagopolice.org/community/distri...
# 22  http://home.chicagopolice.org/community/distri...
#
#                            LOCATION       Latitude       Longitude
# 0   (41.8307016873, -87.6233953459)  41.8307016873  -87.6233953459
# 1   (41.9032416531, -87.6433521393)  41.9032416531  -87.6433521393
# 2    (41.9474004564, -87.651512018)  41.9474004564   -87.651512018
# 3   (41.9795495131, -87.6928445094)  41.9795495131  -87.6928445094
# 4   (41.6914347795, -87.6685203937)  41.6914347795  -87.6685203937
# 5   (41.9997634842, -87.6713242922)  41.9997634842  -87.6713242922
# 6    (41.9186088912, -87.765574479)  41.9186088912   -87.765574479
# 7    (41.8583725929, -87.627356171)  41.8583725929   -87.627356171
# 8   (41.8018110912, -87.6305601801)  41.8018110912  -87.6305601801
# 9   (41.7664308925, -87.6057478606)  41.7664308925  -87.6057478606
# 10  (41.7079332906, -87.5683491228)  41.7079332906  -87.5683491228
# 11  (41.6927233639, -87.6045058667)  41.6927233639  -87.6045058667
# 12  (41.7521368378, -87.6442289066)  41.7521368378  -87.6442289066
# 13  (41.7796315359, -87.6608870173)  41.7796315359  -87.6608870173
# 14   (41.778987189, -87.7088638153)   41.778987189  -87.7088638153
# 15  (41.8373944311, -87.6464077068)  41.8373944311  -87.6464077068
# 16   (41.8566845327, -87.708381958)  41.8566845327   -87.708381958
# 17   (41.8735822883, -87.705488126)  41.8735822883   -87.705488126
# 18  (41.8629766244, -87.6569725149)  41.8629766244  -87.6569725149
# 19  (41.9211033246, -87.6974518223)  41.9211033246  -87.6974518223
# 20   (41.8800834614, -87.768199889)  41.8800834614   -87.768199889
# 21  (41.9740944511, -87.7661488432)  41.9740944511  -87.7661488432
# 22   (41.9660534171, -87.728114561)  41.9660534171   -87.728114561

# %%
filtered_accident_df
# Out:
#      PERSON_ID PERSON_TYPE                                    CRASH_RECORD_ID  \
# 0     O1558342     BICYCLE  b131d8e80f329ed77ed279badb1d3c60f06b108c7f63c7...
# 1     O1558486     BICYCLE  bfce8b092f549a5785e9249d266bb88960d2dc54a08717...
# 2     O1568916     BICYCLE  d313bbafece051a48e92c3de2fd8bbad529bec42fbd1db...
# 3     O1665711     BICYCLE  a5393326d8f3a5c6a4cb2a26efdb4bfead74a915dce707...
# 4     O1666065     BICYCLE  0bdb3396e7f9903245d1800e8b00c767742acdb5fe3507...
# ...        ...         ...                                                ...
# 1285  O1732707     BICYCLE  a16946ff895b6bd97ea39f614d88f6e3c33398965f6fc7...
# 1286  O1732814     BICYCLE  09f44eb6e4805bfc2aceb87fc489436a0a009dac70e7ab...
# 1287  O1744236     BICYCLE  826df47aebca62052e0820cc30ab3054a5026a63de2f48...
# 1288  O1757350     BICYCLE  1e47752a6e5ef4bf88cad14768828e11e96de6f8364726...
# 1289  O1773412     BICYCLE  8aef00211912d35808b709b3946f6c30783cc25ecd4d66...
#
#             CRASH_DATE     CITY STATE ZIPCODE SEX   AGE  \
# 0      4/19/2023 13:45  CHICAGO    IL   60617   M  43.0
# 1      4/19/2023 17:20  CHICAGO    IL   60657   F   0.0
# 2        5/5/2023 8:08  CHICAGO    IL   60626   M  19.0
# 3      9/21/2023 11:03  CHICAGO    IL   60614   M  37.0
# 4      9/21/2023 18:30  CHICAGO    IL   60612   M  18.0
# ...                ...      ...   ...     ...  ..   ...
# 1285  12/30/2023 16:44  CHICAGO    IL   60622   M  24.0
# 1286  12/30/2023 21:53  CHICAGO    IL   60613   M  32.0
# 1287  12/22/2023 18:15  CHICAGO    IL   60639   M  29.0
# 1288  11/29/2023 18:03  CHICAGO    IL   60605   M  26.0
# 1289  12/18/2023 16:30  CHICAGO    IL   60645   M  18.0
#
#                                 SAFETY_EQUIPMENT  ...            HOSPITAL  \
# 0     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...                 NaN
# 1     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...                 NaN
# 2                                HELMET NOT USED  ...                 NaN
# 3                                HELMET NOT USED  ...                 NaN
# 4     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...                 NaN
# ...                                          ...  ...                 ...
# 1285                             HELMET NOT USED  ...  ST. MARYS HOSPITAL
# 1286  BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...                 NaN
# 1287                             HELMET NOT USED  ...            ST MARYS
# 1288  BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...    ILLINOIS MASONIC
# 1289                             HELMET NOT USED  ...                 NaN
#
#      EMS_AGENCY DRIVER_VISION PHYSICAL_CONDITION  \
# 0           NaN       UNKNOWN             NORMAL
# 1           NaN       UNKNOWN             NORMAL
# 2           NaN       UNKNOWN             NORMAL
# 3           NaN  NOT OBSCURED             NORMAL
# 4           NaN  NOT OBSCURED             NORMAL
# ...         ...           ...                ...
# 1285        NaN  NOT OBSCURED             NORMAL
# 1286        NaN  NOT OBSCURED             NORMAL
# 1287        NaN  NOT OBSCURED             NORMAL
# 1288         62       UNKNOWN            UNKNOWN
# 1289        NaN       UNKNOWN            UNKNOWN
#
#                                PEDPEDAL_ACTION      PEDPEDAL_VISIBILITY  \
# 0     CROSSING - NO CONTROLS (AT INTERSECTION)     CONTRASTING CLOTHING
# 1                                 WITH TRAFFIC  NO CONTRASTING CLOTHING
# 2                                 TURNING LEFT  NO CONTRASTING CLOTHING
# 3                    CROSSING - AGAINST SIGNAL  NO CONTRASTING CLOTHING
# 4                       CROSSING - WITH SIGNAL  NO CONTRASTING CLOTHING
# ...                                        ...                      ...
# 1285                              WITH TRAFFIC  NO CONTRASTING CLOTHING
# 1286                                UNKNOWN/NA  NO CONTRASTING CLOTHING
# 1287                                 NO ACTION  NO CONTRASTING CLOTHING
# 1288                              WITH TRAFFIC  NO CONTRASTING CLOTHING
# 1289                              WITH TRAFFIC  NO CONTRASTING CLOTHING
#
#      PEDPEDAL_LOCATION        BAC_RESULT   Latitude  Longitude
# 0           IN ROADWAY  TEST NOT OFFERED  41.720556 -87.555480
# 1              BIKEWAY  TEST NOT OFFERED  41.939384 -87.655629
# 2           IN ROADWAY  TEST NOT OFFERED  42.012763 -87.668274
# 3           IN ROADWAY  TEST NOT OFFERED  41.922401 -87.651560
# 4         IN CROSSWALK  TEST NOT OFFERED  41.879027 -87.686180
# ...                ...               ...        ...        ...
# 1285        IN ROADWAY  TEST NOT OFFERED  41.901307 -87.674636
# 1286         BIKE LANE  TEST NOT OFFERED  41.952681 -87.658991
# 1287           BIKEWAY  TEST NOT OFFERED  41.919423 -87.754785
# 1288         BIKE LANE  TEST NOT OFFERED  58.459688  26.364155
# 1289        IN ROADWAY  TEST NOT OFFERED  42.009352 -87.697004
#
# [1290 rows x 22 columns]

# %%
import pandas as pd
from geopy.distance import geodesic

# Function to calculate distance between two sets of coordinates
def calculate_distance(coord1, coord2):
    return geodesic(coord1, coord2).miles

# Function to find the nearest police station to an accident
def find_nearest_police_station(accident_coords, police_stations):
    min_distance = float('inf')
    nearest_station = None
    for idx, station in police_stations.iterrows():
        station_coords = (station['Latitude'], station['Longitude'])
        distance = calculate_distance(accident_coords, station_coords)
        if distance < min_distance:
            min_distance = distance
            nearest_station = station
    return nearest_station

# Iterate over each accident and find the nearest police station
for idx, accident in filtered_accident_df.iterrows():
    accident_coords = (float(accident['Latitude']), float(accident['Longitude']))
    nearest_station = find_nearest_police_station(accident_coords, police_districts_df)
    # Assign the district of the nearest police station to the accident
    filtered_accident_df.at[idx, 'DISTRICT'] = nearest_station['DISTRICT']

# %%
filtered_accident_df
# Out:
#      PERSON_ID PERSON_TYPE                                    CRASH_RECORD_ID  \
# 0     O1558342     BICYCLE  b131d8e80f329ed77ed279badb1d3c60f06b108c7f63c7...
# 1     O1558486     BICYCLE  bfce8b092f549a5785e9249d266bb88960d2dc54a08717...
# 2     O1568916     BICYCLE  d313bbafece051a48e92c3de2fd8bbad529bec42fbd1db...
# 3     O1665711     BICYCLE  a5393326d8f3a5c6a4cb2a26efdb4bfead74a915dce707...
# 4     O1666065     BICYCLE  0bdb3396e7f9903245d1800e8b00c767742acdb5fe3507...
# ...        ...         ...                                                ...
# 1285  O1732707     BICYCLE  a16946ff895b6bd97ea39f614d88f6e3c33398965f6fc7...
# 1286  O1732814     BICYCLE  09f44eb6e4805bfc2aceb87fc489436a0a009dac70e7ab...
# 1287  O1744236     BICYCLE  826df47aebca62052e0820cc30ab3054a5026a63de2f48...
# 1288  O1757350     BICYCLE  1e47752a6e5ef4bf88cad14768828e11e96de6f8364726...
# 1289  O1773412     BICYCLE  8aef00211912d35808b709b3946f6c30783cc25ecd4d66...
#
#             CRASH_DATE     CITY STATE ZIPCODE SEX   AGE  \
# 0      4/19/2023 13:45  CHICAGO    IL   60617   M  43.0
# 1      4/19/2023 17:20  CHICAGO    IL   60657   F   0.0
# 2        5/5/2023 8:08  CHICAGO    IL   60626   M  19.0
# 3      9/21/2023 11:03  CHICAGO    IL   60614   M  37.0
# 4      9/21/2023 18:30  CHICAGO    IL   60612   M  18.0
# ...                ...      ...   ...     ...  ..   ...
# 1285  12/30/2023 16:44  CHICAGO    IL   60622   M  24.0
# 1286  12/30/2023 21:53  CHICAGO    IL   60613   M  32.0
# 1287  12/22/2023 18:15  CHICAGO    IL   60639   M  29.0
# 1288  11/29/2023 18:03  CHICAGO    IL   60605   M  26.0
# 1289  12/18/2023 16:30  CHICAGO    IL   60645   M  18.0
#
#                                 SAFETY_EQUIPMENT  ... EMS_AGENCY  \
# 0     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...        NaN
# 1     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...        NaN
# 2                                HELMET NOT USED  ...        NaN
# 3                                HELMET NOT USED  ...        NaN
# 4     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...        NaN
# ...                                          ...  ...        ...
# 1285                             HELMET NOT USED  ...        NaN
# 1286  BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...        NaN
# 1287                             HELMET NOT USED  ...        NaN
# 1288  BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...         62
# 1289                             HELMET NOT USED  ...        NaN
#
#      DRIVER_VISION PHYSICAL_CONDITION  \
# 0          UNKNOWN             NORMAL
# 1          UNKNOWN             NORMAL
# 2          UNKNOWN             NORMAL
# 3     NOT OBSCURED             NORMAL
# 4     NOT OBSCURED             NORMAL
# ...            ...                ...
# 1285  NOT OBSCURED             NORMAL
# 1286  NOT OBSCURED             NORMAL
# 1287  NOT OBSCURED             NORMAL
# 1288       UNKNOWN            UNKNOWN
# 1289       UNKNOWN            UNKNOWN
#
#                                PEDPEDAL_ACTION      PEDPEDAL_VISIBILITY  \
# 0     CROSSING - NO CONTROLS (AT INTERSECTION)     CONTRASTING CLOTHING
# 1                                 WITH TRAFFIC  NO CONTRASTING CLOTHING
# 2                                 TURNING LEFT  NO CONTRASTING CLOTHING
# 3                    CROSSING - AGAINST SIGNAL  NO CONTRASTING CLOTHING
# 4                       CROSSING - WITH SIGNAL  NO CONTRASTING CLOTHING
# ...                                        ...                      ...
# 1285                              WITH TRAFFIC  NO CONTRASTING CLOTHING
# 1286                                UNKNOWN/NA  NO CONTRASTING CLOTHING
# 1287                                 NO ACTION  NO CONTRASTING CLOTHING
# 1288                              WITH TRAFFIC  NO CONTRASTING CLOTHING
# 1289                              WITH TRAFFIC  NO CONTRASTING CLOTHING
#
#      PEDPEDAL_LOCATION        BAC_RESULT   Latitude  Longitude DISTRICT
# 0           IN ROADWAY  TEST NOT OFFERED  41.720556 -87.555480        4
# 1              BIKEWAY  TEST NOT OFFERED  41.939384 -87.655629       19
# 2           IN ROADWAY  TEST NOT OFFERED  42.012763 -87.668274       24
# 3           IN ROADWAY  TEST NOT OFFERED  41.922401 -87.651560       18
# 4         IN CROSSWALK  TEST NOT OFFERED  41.879027 -87.686180       11
# ...                ...               ...        ...        ...      ...
# 1285        IN ROADWAY  TEST NOT OFFERED  41.901307 -87.674636       18
# 1286         BIKE LANE  TEST NOT OFFERED  41.952681 -87.658991       19
# 1287           BIKEWAY  TEST NOT OFFERED  41.919423 -87.754785       25
# 1288         BIKE LANE  TEST NOT OFFERED  58.459688  26.364155       24
# 1289        IN ROADWAY  TEST NOT OFFERED  42.009352 -87.697004       24
#
# [1290 rows x 23 columns]

# %%
filtered_accident_df['DISTRICT'].value_counts()
# Out:
# 24              278
# 14              142
# 18              131
# 25               82
# 20               76
# 19               76
# 8                74
# 16               74
# 17               62
# 11               43
# 2                42
# 10               35
# 3                28
# 12               26
# 1                26
# 7                20
# 4                19
# 22               17
# 5                15
# 15               14
# Headquarters     10
# Name: DISTRICT, dtype: int64

# %%
#filtered_accident_df.to_csv("filtered_accident_df.csv")

# %%
filtered_accident_df['DateTime'] = pd.to_datetime(filtered_accident_df['CRASH_DATE'], format='%m/%d/%Y %H:%M')

# %%
filtered_accident_df['Date'] = filtered_accident_df['DateTime'].dt.date

# %%
filtered_accident_df
# Out:
#      PERSON_ID PERSON_TYPE                                    CRASH_RECORD_ID  \
# 0     O1558342     BICYCLE  b131d8e80f329ed77ed279badb1d3c60f06b108c7f63c7...
# 1     O1558486     BICYCLE  bfce8b092f549a5785e9249d266bb88960d2dc54a08717...
# 2     O1568916     BICYCLE  d313bbafece051a48e92c3de2fd8bbad529bec42fbd1db...
# 3     O1665711     BICYCLE  a5393326d8f3a5c6a4cb2a26efdb4bfead74a915dce707...
# 4     O1666065     BICYCLE  0bdb3396e7f9903245d1800e8b00c767742acdb5fe3507...
# ...        ...         ...                                                ...
# 1285  O1732707     BICYCLE  a16946ff895b6bd97ea39f614d88f6e3c33398965f6fc7...
# 1286  O1732814     BICYCLE  09f44eb6e4805bfc2aceb87fc489436a0a009dac70e7ab...
# 1287  O1744236     BICYCLE  826df47aebca62052e0820cc30ab3054a5026a63de2f48...
# 1288  O1757350     BICYCLE  1e47752a6e5ef4bf88cad14768828e11e96de6f8364726...
# 1289  O1773412     BICYCLE  8aef00211912d35808b709b3946f6c30783cc25ecd4d66...
#
#             CRASH_DATE     CITY STATE ZIPCODE SEX   AGE  \
# 0      4/19/2023 13:45  CHICAGO    IL   60617   M  43.0
# 1      4/19/2023 17:20  CHICAGO    IL   60657   F   0.0
# 2        5/5/2023 8:08  CHICAGO    IL   60626   M  19.0
# 3      9/21/2023 11:03  CHICAGO    IL   60614   M  37.0
# 4      9/21/2023 18:30  CHICAGO    IL   60612   M  18.0
# ...                ...      ...   ...     ...  ..   ...
# 1285  12/30/2023 16:44  CHICAGO    IL   60622   M  24.0
# 1286  12/30/2023 21:53  CHICAGO    IL   60613   M  32.0
# 1287  12/22/2023 18:15  CHICAGO    IL   60639   M  29.0
# 1288  11/29/2023 18:03  CHICAGO    IL   60605   M  26.0
# 1289  12/18/2023 16:30  CHICAGO    IL   60645   M  18.0
#
#                                 SAFETY_EQUIPMENT  ... PHYSICAL_CONDITION  \
# 0     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...             NORMAL
# 1     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...             NORMAL
# 2                                HELMET NOT USED  ...             NORMAL
# 3                                HELMET NOT USED  ...             NORMAL
# 4     BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...             NORMAL
# ...                                          ...  ...                ...
# 1285                             HELMET NOT USED  ...             NORMAL
# 1286  BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...             NORMAL
# 1287                             HELMET NOT USED  ...             NORMAL
# 1288  BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)  ...            UNKNOWN
# 1289                             HELMET NOT USED  ...            UNKNOWN
#
#                                PEDPEDAL_ACTION      PEDPEDAL_VISIBILITY  \
# 0     CROSSING - NO CONTROLS (AT INTERSECTION)     CONTRASTING CLOTHING
# 1                                 WITH TRAFFIC  NO CONTRASTING CLOTHING
# 2                                 TURNING LEFT  NO CONTRASTING CLOTHING
# 3                    CROSSING - AGAINST SIGNAL  NO CONTRASTING CLOTHING
# 4                       CROSSING - WITH SIGNAL  NO CONTRASTING CLOTHING
# ...                                        ...                      ...
# 1285                              WITH TRAFFIC  NO CONTRASTING CLOTHING
# 1286                                UNKNOWN/NA  NO CONTRASTING CLOTHING
# 1287                                 NO ACTION  NO CONTRASTING CLOTHING
# 1288                              WITH TRAFFIC  NO CONTRASTING CLOTHING
# 1289                              WITH TRAFFIC  NO CONTRASTING CLOTHING
#
#      PEDPEDAL_LOCATION        BAC_RESULT   Latitude  Longitude DISTRICT  \
# 0           IN ROADWAY  TEST NOT OFFERED  41.720556 -87.555480        4
# 1              BIKEWAY  TEST NOT OFFERED  41.939384 -87.655629       19
# 2           IN ROADWAY  TEST NOT OFFERED  42.012763 -87.668274       24
# 3           IN ROADWAY  TEST NOT OFFERED  41.922401 -87.651560       18
# 4         IN CROSSWALK  TEST NOT OFFERED  41.879027 -87.686180       11
# ...                ...               ...        ...        ...      ...
# 1285        IN ROADWAY  TEST NOT OFFERED  41.901307 -87.674636       18
# 1286         BIKE LANE  TEST NOT OFFERED  41.952681 -87.658991       19
# 1287           BIKEWAY  TEST NOT OFFERED  41.919423 -87.754785       25
# 1288         BIKE LANE  TEST NOT OFFERED  58.459688  26.364155       24
# 1289        IN ROADWAY  TEST NOT OFFERED  42.009352 -87.697004       24
#
#                 DateTime        Date
# 0    2023-04-19 13:45:00  2023-04-19
# 1    2023-04-19 17:20:00  2023-04-19
# 2    2023-05-05 08:08:00  2023-05-05
# 3    2023-09-21 11:03:00  2023-09-21
# 4    2023-09-21 18:30:00  2023-09-21
# ...                  ...         ...
# 1285 2023-12-30 16:44:00  2023-12-30
# 1286 2023-12-30 21:53:00  2023-12-30
# 1287 2023-12-22 18:15:00  2023-12-22
# 1288 2023-11-29 18:03:00  2023-11-29
# 1289 2023-12-18 16:30:00  2023-12-18
#
# [1290 rows x 25 columns]

# %%
# Creating a DataFrame for each accident with the date and the district it happened in 
accidents_districts_date = pd.DataFrame(filtered_accident_df.groupby(['Date', 'DISTRICT'])['PERSON_ID'].count()).reset_index()
accidents_districts_date
# Out:
#             Date DISTRICT  PERSON_ID
# 0     2023-01-01       24          1
# 1     2023-01-03       18          1
# 2     2023-01-04       25          1
# 3     2023-01-04        8          1
# 4     2023-01-07       24          1
# ...          ...      ...        ...
# 1022  2023-12-25       24          1
# 1023  2023-12-27       24          2
# 1024  2023-12-28        1          1
# 1025  2023-12-30       18          2
# 1026  2023-12-30       19          1
#
# [1027 rows x 3 columns]

# %%
#accidents_districts_date.to_csv("accidents_districts_date.csv")

# %%
accidents_districts_date.rename(columns = {'PERSON_ID':'no_of_accidents'}, inplace = True)

# %%
accidents_districts_date
# Out:
#             Date DISTRICT  no_of_accidents
# 0     2023-01-01       24                1
# 1     2023-01-03       18                1
# 2     2023-01-04       25                1
# 3     2023-01-04        8                1
# 4     2023-01-07       24                1
# ...          ...      ...              ...
# 1022  2023-12-25       24                1
# 1023  2023-12-27       24                2
# 1024  2023-12-28        1                1
# 1025  2023-12-30       18                2
# 1026  2023-12-30       19                1
#
# [1027 rows x 3 columns]

# %%
accidents_districts_date.dtypes
# Out:
# Date               object
# DISTRICT           object
# no_of_accidents     int64
# dtype: object

# %%
accidents_districts_date['Date'] = pd.to_datetime(accidents_districts_date['Date'])

# %% [markdown]
# # Creating a dataframe for each day each station and how many accidents happened on that day

# %%
dates_2023 = pd.date_range(start='2023-01-01', end='2023-12-31', freq='D')
date_district_df = pd.DataFrame({'Date': dates_2023})
date_district_df
# Out:
#           Date
# 0   2023-01-01
# 1   2023-01-02
# 2   2023-01-03
# 3   2023-01-04
# 4   2023-01-05
# ..         ...
# 360 2023-12-27
# 361 2023-12-28
# 362 2023-12-29
# 363 2023-12-30
# 364 2023-12-31
#
# [365 rows x 1 columns]

# %%
unique_districts = filtered_accident_df['DISTRICT'].unique()
date_district_df['key'] = 1
district_df = pd.DataFrame({'DISTRICT': unique_districts})
district_df['key'] = 1
cross_join_df = pd.merge(date_district_df, district_df, on='key').drop(columns='key')
cross_join_df
# Out:
#            Date      DISTRICT
# 0    2023-01-01             4
# 1    2023-01-01            19
# 2    2023-01-01            24
# 3    2023-01-01            18
# 4    2023-01-01            11
# ...         ...           ...
# 7660 2023-12-31            12
# 7661 2023-12-31            15
# 7662 2023-12-31             7
# 7663 2023-12-31  Headquarters
# 7664 2023-12-31             5
#
# [7665 rows x 2 columns]

# %%
cross_join_df.dtypes
# Out:
# Date        datetime64[ns]
# DISTRICT            object
# dtype: object

# %%
filtered_accident_df.dtypes
# Out:
# PERSON_ID                        object
# PERSON_TYPE                      object
# CRASH_RECORD_ID                  object
# CRASH_DATE                       object
# CITY                             object
# STATE                            object
# ZIPCODE                          object
# SEX                              object
# AGE                             float64
# SAFETY_EQUIPMENT                 object
# EJECTION                         object
# INJURY_CLASSIFICATION            object
# HOSPITAL                         object
# EMS_AGENCY                       object
# DRIVER_VISION                    object
# PHYSICAL_CONDITION               object
# PEDPEDAL_ACTION                  object
# PEDPEDAL_VISIBILITY              object
# PEDPEDAL_LOCATION                object
# BAC_RESULT                       object
# Latitude                        float64
# Longitude                       float64
# DISTRICT                         object
# DateTime                 datetime64[ns]
# Date                             object
# dtype: object

# %%
filtered_accident_df['Date'] = pd.to_datetime(filtered_accident_df['Date'], format='%Y-%m-%d', errors='coerce')

# %%
filtered_accident_df.dtypes
# Out:
# PERSON_ID                        object
# PERSON_TYPE                      object
# CRASH_RECORD_ID                  object
# CRASH_DATE                       object
# CITY                             object
# STATE                            object
# ZIPCODE                          object
# SEX                              object
# AGE                             float64
# SAFETY_EQUIPMENT                 object
# EJECTION                         object
# INJURY_CLASSIFICATION            object
# HOSPITAL                         object
# EMS_AGENCY                       object
# DRIVER_VISION                    object
# PHYSICAL_CONDITION               object
# PEDPEDAL_ACTION                  object
# PEDPEDAL_VISIBILITY              object
# PEDPEDAL_LOCATION                object
# BAC_RESULT                       object
# Latitude                        float64
# Longitude                       float64
# DISTRICT                         object
# DateTime                 datetime64[ns]
# Date                     datetime64[ns]
# dtype: object

# %%
accidents_per_day_district = pd.merge(cross_join_df, filtered_accident_df, on=['Date', 'DISTRICT'], how='left')
accidents_per_day_district = accidents_per_day_district.groupby(['Date', 'DISTRICT']).size().reset_index(name='Accidents')

# %%
accidents_per_day_district.head(60)
# Out:
#          Date      DISTRICT  Accidents
# 0  2023-01-01             1          1
# 1  2023-01-01            10          1
# 2  2023-01-01            11          1
# 3  2023-01-01            12          1
# 4  2023-01-01            14          1
# 5  2023-01-01            15          1
# 6  2023-01-01            16          1
# 7  2023-01-01            17          1
# 8  2023-01-01            18          1
# 9  2023-01-01            19          1
# 10 2023-01-01             2          1
# 11 2023-01-01            20          1
# 12 2023-01-01            22          1
# 13 2023-01-01            24          1
# 14 2023-01-01            25          1
# 15 2023-01-01             3          1
# 16 2023-01-01             4          1
# 17 2023-01-01             5          1
# 18 2023-01-01             7          1
# 19 2023-01-01             8          1
# 20 2023-01-01  Headquarters          1
# 21 2023-01-02             1          1
# 22 2023-01-02            10          1
# 23 2023-01-02            11          1
# 24 2023-01-02            12          1
# 25 2023-01-02            14          1
# 26 2023-01-02            15          1
# 27 2023-01-02            16          1
# 28 2023-01-02            17          1
# 29 2023-01-02            18          1
# 30 2023-01-02            19          1
# 31 2023-01-02             2          1
# 32 2023-01-02            20          1
# 33 2023-01-02            22          1
# 34 2023-01-02            24          1
# 35 2023-01-02            25          1
# 36 2023-01-02             3          1
# 37 2023-01-02             4          1
# 38 2023-01-02             5          1
# 39 2023-01-02             7          1
# 40 2023-01-02             8          1
# 41 2023-01-02  Headquarters          1
# 42 2023-01-03             1          1
# 43 2023-01-03            10          1
# 44 2023-01-03            11          1
# 45 2023-01-03            12          1
# 46 2023-01-03            14          1
# 47 2023-01-03            15          1
# 48 2023-01-03            16          1
# 49 2023-01-03            17          1
# 50 2023-01-03            18          1
# 51 2023-01-03            19          1
# 52 2023-01-03             2          1
# 53 2023-01-03            20          1
# 54 2023-01-03            22          1
# 55 2023-01-03            24          1
# 56 2023-01-03            25          1
# 57 2023-01-03             3          1
# 58 2023-01-03             4          1
# 59 2023-01-03             5          1

# %%
accidents_per_day_district.dtypes
# Out:
# Date         datetime64[ns]
# DISTRICT             object
# Accidents             int64
# dtype: object

# %%
#accidents_per_day_district.to_csv("accidents_per_day_district.csv")

# %%
accidents_districts_date.head(60)
# Out:
#          Date      DISTRICT  no_of_accidents
# 0  2023-01-01            24                1
# 1  2023-01-03            18                1
# 2  2023-01-04            25                1
# 3  2023-01-04             8                1
# 4  2023-01-07            24                1
# 5  2023-01-08            24                1
# 6  2023-01-10            24                1
# 7  2023-01-12            11                1
# 8  2023-01-13            24                1
# 9  2023-01-15            12                1
# 10 2023-01-15            24                1
# 11 2023-01-17            10                1
# 12 2023-01-18            20                1
# 13 2023-01-18            24                1
# 14 2023-01-19            25                1
# 15 2023-01-21            24                2
# 16 2023-01-24            11                1
# 17 2023-01-24             2                1
# 18 2023-01-24            24                1
# 19 2023-01-25            25                1
# 20 2023-01-26            14                1
# 21 2023-01-27            24                2
# 22 2023-01-28            24                1
# 23 2023-02-02            18                1
# 24 2023-02-04            14                1
# 25 2023-02-04             5                1
# 26 2023-02-05            14                1
# 27 2023-02-05            17                1
# 28 2023-02-06            11                1
# 29 2023-02-07            10                1
# 30 2023-02-07            18                1
# 31 2023-02-08            14                2
# 32 2023-02-08            17                1
# 33 2023-02-10            14                1
# 34 2023-02-10            17                1
# 35 2023-02-11            14                1
# 36 2023-02-11            20                1
# 37 2023-02-11            24                1
# 38 2023-02-12            10                1
# 39 2023-02-12            24                1
# 40 2023-02-14            18                1
# 41 2023-02-14  Headquarters                1
# 42 2023-02-15            17                1
# 43 2023-02-17            24                1
# 44 2023-02-19            19                1
# 45 2023-02-20            20                1
# 46 2023-02-21            14                1
# 47 2023-02-21            22                1
# 48 2023-02-21            24                1
# 49 2023-02-22            16                1
# 50 2023-02-25            18                1
# 51 2023-02-26            19                1
# 52 2023-02-26            24                1
# 53 2023-02-28            18                1
# 54 2023-02-28            19                1
# 55 2023-02-28             3                1
# 56 2023-03-01            20                1
# 57 2023-03-02            14                1
# 58 2023-03-04            14                1
# 59 2023-03-04            25                1

# %%
merged_df = pd.merge(accidents_per_day_district, accidents_districts_date, on=['Date', 'DISTRICT'], how='left')
merged_df.head(60)
# Out:
#          Date      DISTRICT  Accidents  no_of_accidents
# 0  2023-01-01             1          1              NaN
# 1  2023-01-01            10          1              NaN
# 2  2023-01-01            11          1              NaN
# 3  2023-01-01            12          1              NaN
# 4  2023-01-01            14          1              NaN
# 5  2023-01-01            15          1              NaN
# 6  2023-01-01            16          1              NaN
# 7  2023-01-01            17          1              NaN
# 8  2023-01-01            18          1              NaN
# 9  2023-01-01            19          1              NaN
# 10 2023-01-01             2          1              NaN
# 11 2023-01-01            20          1              NaN
# 12 2023-01-01            22          1              NaN
# 13 2023-01-01            24          1              1.0
# 14 2023-01-01            25          1              NaN
# 15 2023-01-01             3          1              NaN
# 16 2023-01-01             4          1              NaN
# 17 2023-01-01             5          1              NaN
# 18 2023-01-01             7          1              NaN
# 19 2023-01-01             8          1              NaN
# 20 2023-01-01  Headquarters          1              NaN
# 21 2023-01-02             1          1              NaN
# 22 2023-01-02            10          1              NaN
# 23 2023-01-02            11          1              NaN
# 24 2023-01-02            12          1              NaN
# 25 2023-01-02            14          1              NaN
# 26 2023-01-02            15          1              NaN
# 27 2023-01-02            16          1              NaN
# 28 2023-01-02            17          1              NaN
# 29 2023-01-02            18          1              NaN
# 30 2023-01-02            19          1              NaN
# 31 2023-01-02             2          1              NaN
# 32 2023-01-02            20          1              NaN
# 33 2023-01-02            22          1              NaN
# 34 2023-01-02            24          1              NaN
# 35 2023-01-02            25          1              NaN
# 36 2023-01-02             3          1              NaN
# 37 2023-01-02             4          1              NaN
# 38 2023-01-02             5          1              NaN
# 39 2023-01-02             7          1              NaN
# 40 2023-01-02             8          1              NaN
# 41 2023-01-02  Headquarters          1              NaN
# 42 2023-01-03             1          1              NaN
# 43 2023-01-03            10          1              NaN
# 44 2023-01-03            11          1              NaN
# 45 2023-01-03            12          1              NaN
# 46 2023-01-03            14          1              NaN
# 47 2023-01-03            15          1              NaN
# 48 2023-01-03            16          1              NaN
# 49 2023-01-03            17          1              NaN
# 50 2023-01-03            18          1              1.0
# 51 2023-01-03            19          1              NaN
# 52 2023-01-03             2          1              NaN
# 53 2023-01-03            20          1              NaN
# 54 2023-01-03            22          1              NaN
# 55 2023-01-03            24          1              NaN
# 56 2023-01-03            25          1              NaN
# 57 2023-01-03             3          1              NaN
# 58 2023-01-03             4          1              NaN
# 59 2023-01-03             5          1              NaN

# %%
merged_df['DISTRICT'].unique()
# Out:
# array(['1', '10', '11', '12', '14', '15', '16', '17', '18', '19', '2',
#        '20', '22', '24', '25', '3', '4', '5', '7', '8', 'Headquarters'],
#       dtype=object)

# %%
merged_df.fillna(0, inplace=True)

# %%
merged_df['no_of_accidents'] = merged_df['no_of_accidents'].astype(int)

# %%
merged_df.drop(columns = ['Accidents'], inplace = True)

# %%
merged_df.dtypes
# Out:
# Date               datetime64[ns]
# DISTRICT                   object
# no_of_accidents             int32
# dtype: object

# %%
merged_df['DISTRICT'].unique()
# Out:
# array(['1', '10', '11', '12', '14', '15', '16', '17', '18', '19', '2',
#        '20', '22', '24', '25', '3', '4', '5', '7', '8', 'Headquarters'],
#       dtype=object)

# %%
####################################

# %%
rides
# Out:
#          Unnamed: 0  rideable_type           started_at             ended_at  \
# 0                 1   classic_bike  2023-01-01 00:02:06  2023-01-01 00:29:46
# 1                 2  electric_bike  2023-01-01 00:03:26  2023-01-01 00:07:23
# 2                 3   classic_bike  2023-01-01 00:04:07  2023-01-01 00:13:56
# 3                 4  electric_bike  2023-01-01 00:04:27  2023-01-01 00:16:52
# 4                 5   classic_bike  2023-01-01 00:04:54  2023-01-01 00:31:52
# ...             ...            ...                  ...                  ...
# 5570257     5719599  electric_bike  2023-12-31 23:53:47  2023-12-31 23:55:54
# 5570258     5719600  electric_bike  2023-12-31 23:55:28  2024-01-01 00:24:15
# 5570259     5719601  electric_bike  2023-12-31 23:56:28  2024-01-01 00:00:43
# 5570260     5719602  electric_bike  2023-12-31 23:57:01  2023-12-31 23:59:26
# 5570261     5719603  electric_bike  2023-12-31 23:58:55  2024-01-01 00:06:08
#
#                               start_station_name start_station_id  \
# 0                       Fairbanks Ct & Grand Ave     TA1305000003
# 1                       Sheridan Rd & Loyola Ave           RP-009
# 2                      Leavitt St & Lawrence Ave     TA1309000015
# 3                        Clark St & Montrose Ave     KA1503000022
# 4                         State St & Randolph St     TA1305000029
# ...                                          ...              ...
# 5570257                   Michigan Ave & Lake St     TA1305000011
# 5570258                     McClurg Ct & Ohio St     TA1306000029
# 5570259                   Michigan Ave & Lake St     TA1305000011
# 5570260                   Michigan Ave & Lake St     TA1305000011
# 5570261  Wolcott (Ravenswood) Ave & Montrose Ave     TA1307000144
#
#                    end_station_name end_station_id  start_lat  start_lng  ...  \
# 0              New St & Illinois St   TA1306000013  41.891847 -87.620580  ...
# 1          Sheridan Rd & Loyola Ave         RP-009  42.001139 -87.661256  ...
# 2              Broadway & Argyle St          13108  41.968885 -87.684001  ...
# 3           Clark St & Montrose Ave   KA1503000022  41.961545 -87.666189  ...
# 4        Indiana Ave & Roosevelt Rd         SL-005  41.884621 -87.627834  ...
# ...                             ...            ...        ...        ...  ...
# 5570257      Michigan Ave & Lake St   TA1305000011  41.886258 -87.624602  ...
# 5570258    Fairbanks Ct & Grand Ave   TA1305000003  41.892036 -87.616815  ...
# 5570259                         NaN            NaN  41.886146 -87.624730  ...
# 5570260                         NaN            NaN  41.886145 -87.624771  ...
# 5570261  Sheridan Rd & Montrose Ave   TA1307000107  41.961456 -87.676323  ...
#
#          started_at_hour    month        ride_time          ride_time_1  \
# 0                      0  2023-01  0 days 00:27:40  2023-01-01 00:02:06
# 1                      0  2023-01  0 days 00:03:57  2023-01-01 00:03:26
# 2                      0  2023-01  0 days 00:09:49  2023-01-01 00:04:07
# 3                      0  2023-01  0 days 00:12:25  2023-01-01 00:04:27
# 4                      0  2023-01  0 days 00:26:58  2023-01-01 00:04:54
# ...                  ...      ...              ...                  ...
# 5570257               23  2023-12  0 days 00:02:07  2023-12-31 23:53:47
# 5570258               23  2023-12  0 days 00:28:47  2023-12-31 23:55:28
# 5570259               23  2023-12  0 days 00:04:15  2023-12-31 23:56:28
# 5570260               23  2023-12  0 days 00:02:25  2023-12-31 23:57:01
# 5570261               23  2023-12  0 days 00:07:13  2023-12-31 23:58:55
#
#         rides_in_minutes  start_date avg_temp  \
# 0                   28.0  2023-01-01     41.0
# 1                    4.0  2023-01-01     41.0
# 2                   10.0  2023-01-01     41.0
# 3                   13.0  2023-01-01     41.0
# 4                   27.0  2023-01-01     41.0
# ...                  ...         ...      ...
# 5570257              3.0  2023-12-31     33.5
# 5570258             29.0  2023-12-31     33.5
# 5570259              5.0  2023-12-31     33.5
# 5570260              3.0  2023-12-31     33.5
# 5570261              8.0  2023-12-31     33.5
#
#                                                  start_end  season  district
# 0          Fairbanks Ct & Grand Ave / New St & Illinois St  Winter        18
# 1        Sheridan Rd & Loyola Ave / Sheridan Rd & Loyol...  Winter        24
# 2         Leavitt St & Lawrence Ave / Broadway & Argyle St  Winter        20
# 3        Clark St & Montrose Ave / Clark St & Montrose Ave  Winter        19
# 4        State St & Randolph St / Indiana Ave & Rooseve...  Winter        18
# ...                                                    ...     ...       ...
# 5570257    Michigan Ave & Lake St / Michigan Ave & Lake St  Winter        18
# 5570258    McClurg Ct & Ohio St / Fairbanks Ct & Grand Ave  Winter        18
# 5570259                                                NaN  Winter        18
# 5570260                                                NaN  Winter        18
# 5570261  Wolcott (Ravenswood) Ave & Montrose Ave / Sher...  Winter        20
#
# [5570262 rows x 25 columns]

# %%
rides.dtypes
# Out:
# Unnamed: 0              int64
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# started_at_day         object
# started_at_month       object
# started_at_hour         int64
# month                  object
# ride_time              object
# ride_time_1            object
# rides_in_minutes      float64
# start_date             object
# avg_temp              float64
# start_end              object
# season                 object
# district               object
# dtype: object

# %%
rides_groupby = pd.DataFrame(rides.groupby(['start_date', 'district', "avg_temp", "season","started_at_day"])['ride_time_1'].count().reset_index())

# %%
rides_groupby
# Out:
#       start_date      district  avg_temp  season started_at_day  ride_time_1
# 0     2023-01-01             1      41.0  Winter         Sunday          534
# 1     2023-01-01            10      41.0  Winter         Sunday           23
# 2     2023-01-01            11      41.0  Winter         Sunday           40
# 3     2023-01-01            12      41.0  Winter         Sunday          266
# 4     2023-01-01            14      41.0  Winter         Sunday          453
# ...          ...           ...       ...     ...            ...          ...
# 8379  2023-12-31             6      33.5  Winter         Sunday            9
# 8380  2023-12-31             7      33.5  Winter         Sunday            6
# 8381  2023-12-31             8      33.5  Winter         Sunday           11
# 8382  2023-12-31             9      33.5  Winter         Sunday           30
# 8383  2023-12-31  Headquarters      33.5  Winter         Sunday           71
#
# [8384 rows x 6 columns]

# %%
# trial 92 instead of 93

# %%
#rides_groupby_filtered = rides_groupby[rides_groupby['district'] != "9"]

# %%
rides_groupby_filtered = rides_groupby

# %%
rides_groupby_filtered
# Out:
#       start_date      district  avg_temp  season started_at_day  ride_time_1
# 0     2023-01-01             1      41.0  Winter         Sunday          534
# 1     2023-01-01            10      41.0  Winter         Sunday           23
# 2     2023-01-01            11      41.0  Winter         Sunday           40
# 3     2023-01-01            12      41.0  Winter         Sunday          266
# 4     2023-01-01            14      41.0  Winter         Sunday          453
# ...          ...           ...       ...     ...            ...          ...
# 8379  2023-12-31             6      33.5  Winter         Sunday            9
# 8380  2023-12-31             7      33.5  Winter         Sunday            6
# 8381  2023-12-31             8      33.5  Winter         Sunday           11
# 8382  2023-12-31             9      33.5  Winter         Sunday           30
# 8383  2023-12-31  Headquarters      33.5  Winter         Sunday           71
#
# [8384 rows x 6 columns]

# %%
rides_groupby_filtered = rides_groupby_filtered.rename(columns = {"district":"DISTRICT", "start_date":"Date"})

# %%
rides_groupby_filtered
# Out:
#             Date      DISTRICT  avg_temp  season started_at_day  ride_time_1
# 0     2023-01-01             1      41.0  Winter         Sunday          534
# 1     2023-01-01            10      41.0  Winter         Sunday           23
# 2     2023-01-01            11      41.0  Winter         Sunday           40
# 3     2023-01-01            12      41.0  Winter         Sunday          266
# 4     2023-01-01            14      41.0  Winter         Sunday          453
# ...          ...           ...       ...     ...            ...          ...
# 8379  2023-12-31             6      33.5  Winter         Sunday            9
# 8380  2023-12-31             7      33.5  Winter         Sunday            6
# 8381  2023-12-31             8      33.5  Winter         Sunday           11
# 8382  2023-12-31             9      33.5  Winter         Sunday           30
# 8383  2023-12-31  Headquarters      33.5  Winter         Sunday           71
#
# [8384 rows x 6 columns]

# %%
rides_groupby_filtered.dtypes
# Out:
# Date               object
# DISTRICT           object
# avg_temp          float64
# season             object
# started_at_day     object
# ride_time_1         int64
# dtype: object

# %%
rides_groupby_filtered['Date'] = pd.to_datetime(rides_groupby_filtered['Date'])

# %%
rides_groupby_filtered.dtypes
# Out:
# Date              datetime64[ns]
# DISTRICT                  object
# avg_temp                 float64
# season                    object
# started_at_day            object
# ride_time_1                int64
# dtype: object

# %%
merged_df
# Out:
#            Date      DISTRICT  no_of_accidents
# 0    2023-01-01             1                0
# 1    2023-01-01            10                0
# 2    2023-01-01            11                0
# 3    2023-01-01            12                0
# 4    2023-01-01            14                0
# ...         ...           ...              ...
# 7660 2023-12-31             4                0
# 7661 2023-12-31             5                0
# 7662 2023-12-31             7                0
# 7663 2023-12-31             8                0
# 7664 2023-12-31  Headquarters                0
#
# [7665 rows x 3 columns]

# %%
merged_df.dtypes
# Out:
# Date               datetime64[ns]
# DISTRICT                   object
# no_of_accidents             int32
# dtype: object

# %%
accidents_final_dataset = pd.merge(merged_df, rides_groupby_filtered, on=['Date', 'DISTRICT'], how='left')
accidents_final_dataset
# Out:
#            Date      DISTRICT  no_of_accidents  avg_temp  season  \
# 0    2023-01-01             1                0      41.0  Winter
# 1    2023-01-01            10                0      41.0  Winter
# 2    2023-01-01            11                0      41.0  Winter
# 3    2023-01-01            12                0      41.0  Winter
# 4    2023-01-01            14                0      41.0  Winter
# ...         ...           ...              ...       ...     ...
# 7660 2023-12-31             4                0      33.5  Winter
# 7661 2023-12-31             5                0      33.5  Winter
# 7662 2023-12-31             7                0      33.5  Winter
# 7663 2023-12-31             8                0      33.5  Winter
# 7664 2023-12-31  Headquarters                0      33.5  Winter
#
#      started_at_day  ride_time_1
# 0            Sunday        534.0
# 1            Sunday         23.0
# 2            Sunday         40.0
# 3            Sunday        266.0
# 4            Sunday        453.0
# ...             ...          ...
# 7660         Sunday          1.0
# 7661         Sunday          5.0
# 7662         Sunday          6.0
# 7663         Sunday         11.0
# 7664         Sunday         71.0
#
# [7665 rows x 7 columns]

# %%
accidents_final_dataset = accidents_final_dataset.rename(columns = {"ride_time_1":"no_of_rides"})

# %%
accidents_final_dataset
# Out:
#            Date      DISTRICT  no_of_accidents  avg_temp  season  \
# 0    2023-01-01             1                0      41.0  Winter
# 1    2023-01-01            10                0      41.0  Winter
# 2    2023-01-01            11                0      41.0  Winter
# 3    2023-01-01            12                0      41.0  Winter
# 4    2023-01-01            14                0      41.0  Winter
# ...         ...           ...              ...       ...     ...
# 7660 2023-12-31             4                0      33.5  Winter
# 7661 2023-12-31             5                0      33.5  Winter
# 7662 2023-12-31             7                0      33.5  Winter
# 7663 2023-12-31             8                0      33.5  Winter
# 7664 2023-12-31  Headquarters                0      33.5  Winter
#
#      started_at_day  no_of_rides
# 0            Sunday        534.0
# 1            Sunday         23.0
# 2            Sunday         40.0
# 3            Sunday        266.0
# 4            Sunday        453.0
# ...             ...          ...
# 7660         Sunday          1.0
# 7661         Sunday          5.0
# 7662         Sunday          6.0
# 7663         Sunday         11.0
# 7664         Sunday         71.0
#
# [7665 rows x 7 columns]

# %%
#accidents_final_dataset.to_csv("accidents_final_dataset.csv")

# %%
accidents_final_dataset.dtypes
# Out:
# Date               datetime64[ns]
# DISTRICT                   object
# no_of_accidents             int32
# avg_temp                  float64
# season                     object
# started_at_day             object
# no_of_rides               float64
# dtype: object

# %%
day_to_binary = {'Saturday': 1,'Sunday': 1,'Monday': 0,'Tuesday': 0,'Wednesday': 0,'Thursday': 0,'Friday': 0}
accidents_final_dataset['is_weekend'] = accidents_final_dataset['started_at_day'].map(day_to_binary)

# %%
seasons_to_binary = {'Winter': 0,'Fall': 1,'Spring': 2,'Summer': 3}
accidents_final_dataset['seasons'] = accidents_final_dataset['season'].map(seasons_to_binary)

# %%
accidents_final_dataset
# Out:
#            Date      DISTRICT  no_of_accidents  avg_temp  season  \
# 0    2023-01-01             1                0      41.0  Winter
# 1    2023-01-01            10                0      41.0  Winter
# 2    2023-01-01            11                0      41.0  Winter
# 3    2023-01-01            12                0      41.0  Winter
# 4    2023-01-01            14                0      41.0  Winter
# ...         ...           ...              ...       ...     ...
# 7660 2023-12-31             4                0      33.5  Winter
# 7661 2023-12-31             5                0      33.5  Winter
# 7662 2023-12-31             7                0      33.5  Winter
# 7663 2023-12-31             8                0      33.5  Winter
# 7664 2023-12-31  Headquarters                0      33.5  Winter
#
#      started_at_day  no_of_rides  is_weekend  seasons
# 0            Sunday        534.0         1.0      0.0
# 1            Sunday         23.0         1.0      0.0
# 2            Sunday         40.0         1.0      0.0
# 3            Sunday        266.0         1.0      0.0
# 4            Sunday        453.0         1.0      0.0
# ...             ...          ...         ...      ...
# 7660         Sunday          1.0         1.0      0.0
# 7661         Sunday          5.0         1.0      0.0
# 7662         Sunday          6.0         1.0      0.0
# 7663         Sunday         11.0         1.0      0.0
# 7664         Sunday         71.0         1.0      0.0
#
# [7665 rows x 9 columns]

# %%
# Replacing the district "Headquarters" with 0 for model prediction 
accidents_final_dataset['DISTRICT_index'] = accidents_final_dataset['DISTRICT'].replace({'Headquarters':"0"})

# %%
accidents_final_dataset
# Out:
#            Date      DISTRICT  no_of_accidents  avg_temp  season  \
# 0    2023-01-01             1                0      41.0  Winter
# 1    2023-01-01            10                0      41.0  Winter
# 2    2023-01-01            11                0      41.0  Winter
# 3    2023-01-01            12                0      41.0  Winter
# 4    2023-01-01            14                0      41.0  Winter
# ...         ...           ...              ...       ...     ...
# 7660 2023-12-31             4                0      33.5  Winter
# 7661 2023-12-31             5                0      33.5  Winter
# 7662 2023-12-31             7                0      33.5  Winter
# 7663 2023-12-31             8                0      33.5  Winter
# 7664 2023-12-31  Headquarters                0      33.5  Winter
#
#      started_at_day  no_of_rides  is_weekend  seasons DISTRICT_index
# 0            Sunday        534.0         1.0      0.0              1
# 1            Sunday         23.0         1.0      0.0             10
# 2            Sunday         40.0         1.0      0.0             11
# 3            Sunday        266.0         1.0      0.0             12
# 4            Sunday        453.0         1.0      0.0             14
# ...             ...          ...         ...      ...            ...
# 7660         Sunday          1.0         1.0      0.0              4
# 7661         Sunday          5.0         1.0      0.0              5
# 7662         Sunday          6.0         1.0      0.0              7
# 7663         Sunday         11.0         1.0      0.0              8
# 7664         Sunday         71.0         1.0      0.0              0
#
# [7665 rows x 10 columns]

# %%
accidents_final_dataset['DISTRICT_index'] = accidents_final_dataset['DISTRICT_index'].astype(int)

# %%
accidents_final_dataset.groupby("started_at_day")['no_of_accidents'].sum()
# Out:
# started_at_day
# Friday       210
# Monday       164
# Saturday     166
# Sunday       118
# Thursday     222
# Tuesday      210
# Wednesday    200
# Name: no_of_accidents, dtype: int32

# %%
accidents_final_dataset.groupby("DISTRICT")['no_of_accidents'].sum().sort_values()
# Out:
# DISTRICT
# Headquarters     10
# 15               14
# 5                15
# 22               17
# 4                19
# 7                20
# 1                26
# 12               26
# 3                28
# 10               35
# 2                42
# 11               43
# 17               62
# 8                74
# 16               74
# 19               76
# 20               76
# 25               82
# 18              131
# 14              142
# 24              278
# Name: no_of_accidents, dtype: int32

# %%
corr = np.abs(accidents_final_dataset.corr())

#Set up mask for triangle representation
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))
# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask,  vmax=1,square=True, linewidths=.5, cbar_kws={"shrink": .5},annot = corr)

plt.show()
